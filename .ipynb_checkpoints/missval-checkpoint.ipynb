# %%
import pandas as pd
import matplotlib.pyplot as plt
import pandas_bokeh as pb
from bokeh.plotting import figure, show
from bokeh.io import output_notebook, export_png, output_file
from bokeh.layouts import row, gridplot
from bokeh.models import ColumnDataSource
import numpy as np
import random
# import seaborn as sns; sns.set()
# %matplotlib inline
# pb.output_notebook()
# output_notebook()

# %%
# 已知规则
# 1. 客户来源_原始 如果该字段为空，则自动填充为 展厅

# %%
basedir = "/home/orin/Learning/Data"

# %%
dFilename = "2020年10月潜客数据-模拟.xlsx"
cFilename = "车型代码20201111_F.xlsx"

# %%
# databookALL = pd.read_excel("%s/%s" % (basedir, dFilename), sheet_name=0)

# %%
# databook.to_pickle("potential.pkl")
databook = pd.read_pickle("potential.modify.pkl")

# %%
# databook = databookALL.drop(['车型', '大区', '客户来源更新', '月份'], axis=1)
# databook = databookALL.copy()

# %%
# 客户来源_原始 中 所有NaN值 都会赋值为展厅
databook['客户来源更新'] = databook['客户来源_原始'].fillna('展厅')

# %%
databook['月份'] = databook['日期'].apply(lambda x: str(x.month)+"月")

# %%
# 这个部分只是当前可用，后续还是要使用配置文件导入
# areaDict = dict(databook[['大区名称', '大区']].drop_duplicates().values.tolist())

# %%
# setting.xlsx 格式
# 每个sheet的名字会被用来作为字段映射时的字典名，所以最好用英文，比如现在setting里的sheet名就是"cartype","bigarea"
# 同时，sheet的内容是一个字段的映射关系，比如 大区名称->大区
#      A    B
#  1  东北区 A1
# 这样读取的时候就可以按照下面去读了
tExcel = pd.read_excel("setting.xlsx", sheet_name=None)

# %%
# 这里settingHash就是未来做dataframe.map()用的
settingHash = {}
for keys in tExcel:
    settingHash[keys] = dict(tExcel[keys].values)

# %%
tExcel.keys()
# Out:
# dict_keys(['cartype', 'bigarea'])

# %%
databook['大区'] = databook['大区名称'].map(settingHash['bigarea'])

# %%
databook['车型new'] = databook['分组名称'].map(settingHash['cartype'])

# %%
# map的方式举例，m没用，但是建议将其保留，备以后查
# 当有新的车型进来时，可以在这里看到。
m = pd.DataFrame({'a':databook['分组名称'].head(200), 'b':databook['分组名称'].head(200)})
m['b'] = m['a'].map(settingHash['cartype'])
m.drop_duplicates(['a','b'],  'first')
# Out:
#               a       b
# 0           A4L     A4L
# 1           A6L     A6L
# 2            Q3      Q3
# 3           Q5L     Q5L
# 5       S+Niche  others
# 6           NaN     NaN
# 14       e-tron  e-tron
# 18           Q7      Q7
# 22       A5 SpB      A5
# 23       A6 FBU  A6 FBU
# 25          Q2L     Q2L
# 34       A4 FBU  A4 FBU
# 41     A6L PHEV     A6L
# 42           A7      A7
# 43          A8L     A8L
# 50           Q8      Q8
# 57   FBU Others  others
# 58          HPV  others
# 80       A3 SpB      A3
# 122      Q2 BEV     Q2L
# 161      Q3 SPB      Q3

# %%
def genHash(fname):
    # 配置文件名： configname.txt/configname.csv
    # 配置文件格式应该使用： key, value
    tmp = []
    with open("Data/%s" % fname) as f:
        for line in f:
            lines = line.strip().split(",")
            tmp.append(lines)
    return dict(tmp)

# %%
def transArr(df):
    # 将 [[A4L, 10], [A6, 5]], 这种类型的改成10个A4L，5个A6
    # [A4L, A4L, A4L, A4L, A4L, A4L, A4L, A4L, A4L, A4L, A6, A6, A6, A6, A6]
    # 方便后面按照随机取数出来，这样取出来应该就是这种分布
    tmp = []
    for idx, row in df.iterrows():
        tmp.extend([row['车型new']] * row['潜客量'])
    return tmp

# %%
# 清空dataMiss时，要用这种办法
# dataMiss.drop(dataMiss.index, inplace=True)

# %%
def genNewData(dCode, cSource, nowPOS):
    # dCode 经销商代码
    # cSource 客户来源更新
    # 进来后再做循环
    tmpArr = transArr(dataCOMPUTed[(dataCOMPUTed['经销商代码']==dCode)&(dataCOMPUTed['客户来源更新']==cSource)&(dataCOMPUTed['潜客量']>0)][['车型new', '潜客量']])
    # print(len(tmpArr))
    for idx, row in dataBYday[(dataBYday['经销商代码']==dCode)&(dataBYday['客户来源更新']==cSource)].iterrows():
        toDel = []
        # print(range(len(tmpArr)), row['潜客量'])
        for aIDX in random.sample(range(len(tmpArr)), int(row['潜客量'])):
            dataMiss.loc[nowPOS] = [
                pd.to_datetime(row['日期']),
                row['大区名称'],
                row['小区名称'],
                row['经销商代码'],
                row['经销商名称'],
                row['城市'],
                1,
                np.nan,
                row['客户来源更新'],
                tmpArr[aIDX]
            ]
            nowPOS +=1 
            toDel.append(aIDX)
        for i in sorted(toDel, reverse=True):
            del(tmpArr[i])
    return nowPOS

# %%
def tempDF(lvl, df):
    tmp = df[[lvl, '客户来源更新', '车型new', '潜客量']].copy()
    tmp = tmp.groupby([lvl, '客户来源更新', '车型new'])['潜客量'].sum().reset_index()
    tmp['%s汇总' % lvl] = tmp.groupby([lvl, '客户来源更新'])['潜客量'].transform('sum')
    tmp['车型占比'] = tmp['潜客量']/tmp['%s汇总' % lvl]
    tmp.drop(['潜客量', '%s汇总' % lvl], axis=1, inplace=True)
    return tmp

# %%
def batDraw(lvl):
    graphics = []
    vals = list(getIDX(lvl, dataUSEstd))
    df_o = tempDF(lvl, dataUSEstd)
    df_c = tempDF(lvl, dataEsti)

    for t in ["展厅", "线上"]:
        tmp = []
        for i in vals:
            tmp.append(drawGraph(
                df_o[(df_o[lvl]==i)&(df_o['客户来源更新']==t)][['车型new', '车型占比']],
                df_c[(df_c[lvl]==i)&(df_c['客户来源更新']==t)][['车型new', '车型占比']],
                '%s %s' % (i, t)
            ))
        graphics.append(tmp)

    return graphics

# %%
def drawGraph(se1, se2, title):
# def drawGraph(tmpdf, title):
    tmpdf = se1.merge(se2, on=['车型new'], suffixes=['_origin', '_fix'])
    m = tmpdf.plot_bokeh(kind='barh', legend='top_right', x='车型new', title=title, show_figure=False, zooming=False)
    return m

# %%
def resetType(ser):
    if pd.isnull(ser['分组名称']):
        return np.nan
    else:
        return ser['车型']

# %%
def covTypes(df):
    for col in df.columns:
        if col == '潜客量':
            df[col] = df[col].astype('int32')
        elif col== '日期':
            continue
        else:
            df[col] = df[col].astype('category')

# %%
def getIDX(cName, df, c=6):
    # 在df[cName]的最高30%里，随机取c个作为输出
    # 用于将来的分布验证
    tmp = df[[cName, '潜客量']].groupby([cName])['潜客量'].sum().reset_index()
    tmplist = df[cName].unique()
    if int(len(tmplist)*0.3) <= c:
        tmpidx = tmp.sort_values(by='潜客量', ascending=False).index.values
    else:
        tmpidx = tmp.sort_values(by='潜客量', ascending=False)[:int(len(tmplist)*0.3)].index.values
    return np.array(tmp[cName].iloc[random.sample(list(tmpidx), c)])

# %%
def balanceCom(rows):
    # 根据差值选择计算方式
    if rows['差值'] < 0:
        if rows['已进位'] and rows['顺序']+rows['差值']<=0:
            return rows['预计算潜客2'] - 1
    elif rows['差值'] > 0:
        if (not rows['已进位']) and rows['顺序'] - rows['差值'] <= 0:
            return rows['预计算潜客2'] + 1
    return rows['预计算潜客2']

# %%
def getColumns(col, vals,ty):
    # 获取画图的列
    oriData = dataUSEstd[(dataUSEstd[col]==vals)&(dataUSEstd['客户来源更新']==ty)][['车型new', '车型占比']]
    comData = dataEsti[(dataEsti[col]==vals)&(dataEsti['客户来源更新']==ty)][['车型new', '车型占比']]
    # oriData = statRES(col, dataUSEstd)[]
    return oriData.merge(comData, on='车型new', suffixes=['_origin', '_fix'])

# %%
covTypes(databook)

# %%
# 实际上不需要这一步u
# databook['车型new'] = databook.apply(resetType, axis=1)

# %%
# 这里确实要删掉 分组名称，因为分组和车型new是多对一，如果不删，将来merge回来时，分组名称会为NaN
dataAvailable = databook[databook['车型new'].notna()]
dataAvailable = dataAvailable.drop(['分组名称'], axis=1)

# %%
dataMiss = pd.DataFrame(columns=list(dataAvailable.columns))

# %%
# 做到这里保存，之后就不必继续保存了
# databook.to_pickle("potential.modify.pkl")

# %%
dataUSE = databook[['客户来源更新', '大区名称', '小区名称', '城市', '经销商代码', '车型new', '潜客量']].copy()

# %%
cityLIST = dataUSE['城市'].unique()
area1LIST = dataUSE['大区名称'].unique()
area2LIST = dataUSE['小区名称'].unique()
dealerLIST = dataUSE['经销商代码'].unique()
print(len(area1LIST), len(area2LIST), len(cityLIST), len(dealerLIST))
# Out:
# 6 56 242 553

# %%
monthDays = len(databook['日期'].unique())

# %%
databook.head()
# Out:
#           日期 大区名称  小区名称    经销商代码    经销商名称  城市 分组名称 客户来源_原始  潜客量 客户来源更新   月份  \
# 0 2020-10-01  北部区  北京1区  SA11043  北京奥吉通国门  北京  A4L      展厅    1     展厅  10月
# 1 2020-10-01  北部区  北京1区  SA11043  北京奥吉通国门  北京  A6L      展厅    2     展厅  10月
# 2 2020-10-01  北部区  北京1区  SA11043  北京奥吉通国门  北京   Q3      展厅    1     展厅  10月
# 3 2020-10-01  北部区  北京1区  SA11043  北京奥吉通国门  北京  Q5L      展厅    1     展厅  10月
# 4 2020-10-01  北部区  北京1区  SA11043  北京奥吉通国门  北京  Q5L      线上    2     线上  10月
#
#    大区 车型new
# 0  A3   A4L
# 1  A3   A6L
# 2  A3    Q3
# 3  A3   Q5L
# 4  A3   Q5L

# %%
databook.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65535 entries, 0 to 65534
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   日期       65535 non-null  category
#  1   大区名称     65535 non-null  category
#  2   小区名称     65535 non-null  category
#  3   经销商代码    65535 non-null  category
#  4   经销商名称    65535 non-null  category
#  5   城市       65535 non-null  category
#  6   分组名称     59647 non-null  category
#  7   客户来源_原始  65508 non-null  category
#  8   潜客量      65535 non-null  int32
#  9   客户来源更新   65535 non-null  category
#  10  月份       65535 non-null  category
#  11  大区       65535 non-null  category
#  12  车型new    59647 non-null  category
# dtypes: category(12), int32(1)
# memory usage: 1.2 MB

# %%
dataBYday = databook[databook['车型new'].isna()].groupby(['日期', '大区名称', '小区名称', '经销商代码', '经销商名称', '城市', '客户来源更新'])['潜客量'].sum().reset_index()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-27-5be1f836033d> in <module>
# ----> 1 dataBYday = databook[databook['车型new'].isna()].groupby(['日期', '大区名称', '小区名称', '经销商代码', '经销商名称', '城市', '客户来源更新'])['潜客量'].sum().reset_index()
#
# ~/.local/lib/python3.9/site-packages/pandas/core/groupby/groupby.py in sum(self, numeric_only, min_count)
#    1655             )
#    1656
# -> 1657         return self._reindex_output(result, fill_value=0)
#    1658
#    1659     @final
#
# ~/.local/lib/python3.9/site-packages/pandas/core/groupby/groupby.py in _reindex_output(self, output, fill_value)
#    2884
#    2885         levels_list = [ping.group_index for ping in groupings]
# -> 2886         index, _ = MultiIndex.from_product(
#    2887             levels_list, names=self.grouper.names
#    2888         ).sortlevel()
#
# ~/.local/lib/python3.9/site-packages/pandas/core/indexes/multi.py in from_product(cls, iterables, sortorder, names)
#     593
#     594         # codes are all ndarrays, so cartesian_product is lossless
# --> 595         codes = cartesian_product(codes)
#     596         return cls(levels, codes, sortorder=sortorder, names=names)
#     597
#
# ~/.local/lib/python3.9/site-packages/pandas/core/reshape/util.py in cartesian_product(X)
#      52         b = np.zeros_like(cumprodX)
#      53
# ---> 54     return [tile_compat(np.repeat(x, b[i]), np.product(a[i])) for i, x in enumerate(X)]
#      55
#      56
#
# ~/.local/lib/python3.9/site-packages/pandas/core/reshape/util.py in <listcomp>(.0)
#      52         b = np.zeros_like(cumprodX)
#      53
# ---> 54     return [tile_compat(np.repeat(x, b[i]), np.product(a[i])) for i, x in enumerate(X)]
#      55
#      56
#
# <__array_function__ internals> in repeat(*args, **kwargs)
#
# ~/.local/lib/python3.9/site-packages/numpy/core/fromnumeric.py in repeat(a, repeats, axis)
#     478
#     479     """
# --> 480     return _wrapfunc(a, 'repeat', repeats, axis=axis)
#     481
#     482
#
# ~/.local/lib/python3.9/site-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      56
#      57     try:
# ---> 58         return bound(*args, **kwds)
#      59     except TypeError:
#      60         # A TypeError occurs if the object does have such a method in its
#
# MemoryError: Unable to allocate 509. GiB for an array with shape (546061469184,) and data type int8

# %%
# dealerDISTbd = databook[dataUSE['车型new'].notna()][["日期", "经销商代码", "客户来源更新", "车型new", "潜客量"]]

# %%
# 计算 经销商 客户来源 和车型 的group by sum，去掉日期来计算概率
# sum(经销商、客户来源、车型)/monthDays 这就是某经销商在某来源下车型出现的概率
# dealerDISTbd.groupby(["经销商代码", "客户来源更新", "车型new", "日期"])["潜客量"].sum().reset_index()
# 按日的做起来太麻烦所以不用这个了

# %%
dataUSEstd = dataUSE[dataUSE['车型new'].notna()]
dataUSE2b = dataUSE[dataUSE['车型new'].isna()]

# %%
# 汇总车型数据
dataUSEstd = dataUSEstd.groupby(['大区名称', '小区名称', '城市', '经销商代码', '客户来源更新', '车型new'])['潜客量'].sum().reset_index()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-33-b6324a786403> in <module>
#       1 # 汇总车型数据
# ----> 2 dataUSEstd = dataUSEstd.groupby(['大区名称', '小区名称', '城市', '经销商代码', '客户来源更新', '车型new'])['潜客量'].sum().reset_index()
#
# ~/.local/lib/python3.9/site-packages/pandas/core/groupby/groupby.py in sum(self, numeric_only, min_count)
#    1655             )
#    1656
# -> 1657         return self._reindex_output(result, fill_value=0)
#    1658
#    1659     @final
#
# ~/.local/lib/python3.9/site-packages/pandas/core/groupby/groupby.py in _reindex_output(self, output, fill_value)
#    2884
#    2885         levels_list = [ping.group_index for ping in groupings]
# -> 2886         index, _ = MultiIndex.from_product(
#    2887             levels_list, names=self.grouper.names
#    2888         ).sortlevel()
#
# ~/.local/lib/python3.9/site-packages/pandas/core/indexes/multi.py in sortlevel(self, level, ascending, sort_remaining)
#    2418                 sortorder = level[0]
#    2419
# -> 2420             indexer = indexer_from_factorized(primary, primshp, compress=False)
#    2421
#    2422             if not ascending:
#
# ~/.local/lib/python3.9/site-packages/pandas/core/sorting.py in indexer_from_factorized(labels, shape, compress)
#     250
#     251 def indexer_from_factorized(labels, shape, compress: bool = True):
# --> 252     ids = get_group_index(labels, shape, sort=True, xnull=False)
#     253
#     254     if not compress:
#
# ~/.local/lib/python3.9/site-packages/pandas/core/sorting.py in get_group_index(labels, shape, sort, xnull)
#     138     labels = map(ensure_int64, labels)
#     139     if not xnull:
# --> 140         labels, shape = map(list, zip(*map(maybe_lift, labels, shape)))
#     141
#     142     labels = list(labels)
#
# pandas/_libs/algos_common_helper.pxi in pandas._libs.algos.ensure_int64()
#
# MemoryError: Unable to allocate 10.1 GiB for an array with shape (1348966080,) and data type int64

# %%
# 创建一个基于车型的城市分布
# 因为后续会有部分经销商没有对应 "客户来源更新" 的分布，比如某些经销商没有线上的已有数据作为基准，这时就用城市的替换
# dataCITYstd = dataUSEstd.groupby(['城市', '客户来源更新', '车型new'])['潜客量'].sum().reset_index()
dataCITYstd = dataUSEstd.groupby(['城市', '车型new'])['潜客量'].sum().reset_index()

# %%
# 可能存在来源更新没有的情况，处理起来太复杂，直接用城市了
# dataCITYstd['城市汇总'] = dataCITYstd.groupby(['城市', '客户来源更新'])['潜客量'].transform('sum')
dataCITYstd['城市汇总'] = dataCITYstd.groupby(['城市'])['潜客量'].transform('sum')
dataCITYstd['车型占比'] = dataCITYstd['潜客量']/ dataCITYstd['城市汇总']

# %%
dataUSEstd['dealer汇总'] = dataUSEstd.groupby(['大区名称', '小区名称', '城市', '经销商代码', '客户来源更新'])['潜客量'].transform('sum')
dataUSEstd['车型占比'] = dataUSEstd['潜客量']/dataUSEstd['dealer汇总']
dataUSEstd['日均概率'] = dataUSEstd['潜客量']/monthDays

# %%
dataUSE2b = dataUSE2b.groupby(['大区名称', '小区名称', '城市', '经销商代码', '客户来源更新'])['潜客量'].sum().reset_index()

# %%
dataUSEstd['潜客量'].sum()
# Out:
# 314970

# %%
dataUSE2b['潜客量'].sum()
# Out:
# 66503

# %%
datatmp = dataUSE2b.copy()

# %%
datatmp = datatmp.merge(dataUSEstd[["经销商代码", "客户来源更新", "车型new", "车型占比"]], on=["经销商代码", "客户来源更新"], how='left')

# %%
noneSTD = datatmp[datatmp['车型占比'].isna()]

# %%
datatmp = datatmp[datatmp['车型占比'].notna()]

# %%
noneSTD.drop(['车型new', '车型占比'], axis=1, inplace=True)

# %%
noneSTD = noneSTD.merge(dataCITYstd[['城市', '车型new', '车型占比']], on=['城市'])

# %%
datatmp = pd.concat([datatmp, noneSTD], ignore_index=True)

# %%
# 预计算潜客1 是未四舍五入的值， 预计算潜客2 是四舍五入后的值
datatmp['预计算潜客'] = datatmp["潜客量"] * datatmp["车型占比"]
datatmp['预计算潜客1'] = datatmp['预计算潜客'].map(int)
datatmp['预计算潜客2'] = datatmp['预计算潜客'].apply(lambda x: int(x+0.5))
datatmp['进位可能'] = datatmp['预计算潜客'] - datatmp['预计算潜客1']

# %%
datatmp.head(20)
datatmp['预计算潜客'].sum()
# Out:
# 66503.0

# %%
# 这里计算出来的 差值 就是四舍五入后的差异，需要用这个差异去修改 datatmp
# 里的 预计算潜客2 中不合适的部分。
# 并在 datatmp 中插入新的列 调整潜客
# 所以需要利用 进位可能，进行多退少补：
#     如果需要退n个（差值为负），则寻找 进位可能 > 0.5的数据里最小的n个各去掉 1
#     如果需要补n个（差值为正），则寻找 进位可能 < 0.5的数据里最大的n个各增加 1
# 这部分需要使用函数计算，感觉还比较麻烦
# 这里直接做一个 进位可能 相关的函数，主要是插入 顺序 字段，值是序数：
#   大于 0.5 的 升序，比如：
#     进位可能: [0.51, 0.66, 0.501, 0.7]
#        顺序: [1, 2, 0, 3]
#   小于 0.5 的 降序
##########################################

# %%
# 1. 给 datatemp 增加一列，区分 0.5
datatmp['已进位'] = datatmp['进位可能'] >= 0.5

# %%
# 都使用的升序，处理时要注意
# 先处理 已进位 为 True的
datatmp['顺序'] = 0
l = datatmp['顺序'] + datatmp[datatmp['已进位']==True].groupby(['经销商代码', '客户来源更新', '已进位'])['进位可能'].rank(ascending=True, method="first").astype('int')
r = datatmp['顺序'] + datatmp[datatmp['已进位']==False].groupby(['经销商代码', '客户来源更新', '已进位'])['进位可能'].rank(ascending=False, method="first").astype('int')
datatmp['顺序'] = l.fillna(0) + r.fillna(0)

# %%
# 计算经销商分来源的预计算潜客2的汇总
dataUSEpre = datatmp.groupby(['大区名称', '小区名称', '城市', '经销商代码', '客户来源更新'])['预计算潜客2'].sum().reset_index()

# %%
#dataUSEadj = datatmp.groupby(['大区名称', '小区名称', '城市', '经销商代码', '客户来源更新'])['预计算潜客2'].sum().reset_index()
#dataUSEadj = dataUSE2b.head(200).merge(dataUSEpre[['经销商代码', '客户来源更新', '预计算潜客2']], on=['经销商代码', '客户来源更新'])
dataUSEadj = dataUSE2b.merge(dataUSEpre[['经销商代码', '客户来源更新', '预计算潜客2']], on=['经销商代码', '客户来源更新'])
dataUSEadj['差值'] = dataUSEadj['潜客量'] - dataUSEadj['预计算潜客2']

# %%
dataUSEadj['潜客量'].sum()
# Out:
# 66503

# %%
# 将 差值 合并进 datatmp
datatmp = datatmp.merge(dataUSEadj[['经销商代码', '客户来源更新', '差值']], on=['经销商代码', '客户来源更新'])

# %%
datatmp['预计算真值'] = datatmp.apply(balanceCom, axis=1)

# %%
datatmp['预计算真值'].sum()
# Out:
# 66503

# %%
# 这里开始合并模拟结果和真实结果

# %%
dataCOMPUTed = datatmp[['大区名称', '小区名称', '城市', '经销商代码', '客户来源更新','车型new', '预计算真值']].copy()

# %%
dataCOMPUTed.rename(columns={'预计算真值': '潜客量'}, inplace=True)
dataCOMPUTed.head()
# Out:
#   大区名称  小区名称   城市    经销商代码 客户来源更新   车型new  潜客量
# 0  东北区  吉林小区  兴安盟  SA15016     展厅      A3    1
# 1  东北区  吉林小区  兴安盟  SA15016     展厅  A4 FBU    1
# 2  东北区  吉林小区  兴安盟  SA15016     展厅     A4L    3
# 3  东北区  吉林小区  兴安盟  SA15016     展厅  A6 FBU    3
# 4  东北区  吉林小区  兴安盟  SA15016     展厅     A6L    6

# %%
dataEsti = dataCOMPUTed.append(dataUSEstd[['大区名称', '小区名称', '城市', '经销商代码', '客户来源更新','车型new', '潜客量']])

# %%
dataEsti = dataEsti.groupby(['大区名称', '小区名称', '城市', '经销商代码', '客户来源更新','车型new'])['潜客量'].sum().reset_index()

# %%
# 添加车型站比
dataEsti['dealer汇总'] = dataEsti.groupby(['大区名称', '小区名称', '城市', '经销商代码', '客户来源更新'])['潜客量'].transform('sum')
dataEsti['车型占比'] = dataEsti['潜客量']/dataEsti['dealer汇总']
dataEsti['日均概率'] = dataEsti['潜客量']/monthDays

# %%
dataEsti['潜客量'].sum()
# Out:
# 381473

# %%
#### 以下是之前处理的结果

# %%
def summarySTAT():
    totalPotentials = databook['潜客量'].sum()
    # dealPotentialsbyDay = databook.groupby(['经销商代码', '日期'])['潜客量'].sum().reset_index()
    totalDealPotentials = databook.groupby(['经销商代码'])['潜客量'].sum().reset_index()
    totalPotentialsFIX = dataEsti['潜客量'].sum()
    # dealPotentialsbyDayFIX = dataEsti.groupby(['经销商代码', '日期'])['潜客量'].sum().reset_index()
    totalDealPotentialsFIX = dataEsti.groupby(['经销商代码'])['潜客量'].sum().reset_index()
    # dealDiffbyDay = dealPotentialsbyDay.merge(dealPotentialsbyDayFIX, on=['经销商代码', '日期'], suffixes=['_origin', '_fix'])
    dealDiff = totalDealPotentials.merge(totalDealPotentialsFIX, on=['经销商代码'], suffixes=['_origin', '_fix'])
    # dealDiffbyDay['差值'] = dealDiffbyDay['潜客量_origin'] - dealDiffbyDay['潜客量_fix']
    dealDiff['差值'] = dealDiff['潜客量_origin'] - dealDiff['潜客量_fix']
    print(dealDiff['差值'].value_counts())
    return totalPotentials - totalPotentialsFIX, dealDiff['差值'].value_counts()

# %%
dealerUnique = dataCOMPUTed[['大区名称', '小区名称', '经销商代码', '城市', '客户来源更新']].drop_duplicates()
dealerUnique = dealerUnique.reset_index(drop=True)[['经销商代码', '客户来源更新']]

# %%
dataCOMPUTed[(dataCOMPUTed['经销商代码']=='SA22015')&(dataCOMPUTed['客户来源更新']=='展厅')&(dataCOMPUTed['潜客量']>0)][['车型new', '潜客量']]
# Out:
#      车型new  潜客量
# 36     A4L    5
# 37     A6L    5
# 39     Q2L    1
# 40      Q3    1
# 41     Q5L    5
# 44  others    1

# %%
dealerUnique
# Out:
#         经销商代码 客户来源更新
# 0     SA15016     展厅
# 1     SA22002     展厅
# 2     SA22002     线上
# 3     SA22015     展厅
# 4     SA22015     线上
# 5     SA22009     展厅
# 6     SA22009     线上
# 7     SA22010     线上
# 8     SA22001     展厅
# 9     SA22001     线上
# 10    SA22003     展厅
# 11    SA22003     线上
# 12    SA22008     展厅
# 13    SA22008     线上
# 14    SA22012     展厅
# 15    SA22012     线上
# 16    SA22016     展厅
# 17    SA22016     线上
# 18    SA21018     展厅
# 19    SA21018     线上
# 20    SA21002     展厅
# 21    SA21002     线上
# 22    SA21006     展厅
# 23    SA21006     线上
# 24    SA21013     展厅
# 25    SA21013     线上
# 26    SA21016     展厅
# 27    SA21016     线上
# 28    SA21024     展厅
# 29    SA21024     线上
# ...       ...    ...
# 1011  SA61005     展厅
# 1012  SA61005     线上
# 1013  SA61012     线上
# 1014  SA61015     线上
# 1015  SA61001     展厅
# 1016  SA61001     线上
# 1017  SA61003     展厅
# 1018  SA61003     线上
# 1019  SA61006     展厅
# 1020  SA61006     线上
# 1021  SA61007     展厅
# 1022  SA61007     线上
# 1023  SA61011     展厅
# 1024  SA61011     线上
# 1025  SA61016     展厅
# 1026  SA61016     线上
# 1027  SA61018     展厅
# 1028  SA61018     线上
# 1029  SA33515     线上
# 1030  SA35508     线上
# 1031  SA32080     线上
# 1032  SA34025     线上
# 1033  SA34707     线上
# 1034  SA41021     线上
# 1035  SA36001     线上
# 1036  SA44071     线上
# 1037  SA44063     线上
# 1038  SA43021     线上
# 1039  SA51030     线上
# 1040  SA54001     线上
#
# [1041 rows x 2 columns]

# %%
dataBYday[(dataBYday['经销商代码']=='SA22015')&(dataBYday['客户来源更新']=='展厅')]
# Out:
#               日期 大区名称  小区名称    经销商代码 经销商名称  城市 客户来源更新  潜客量
# 2     2020-10-01  东北区  吉林小区  SA22015  神州华奥  吉林     展厅    2
# 517   2020-10-02  东北区  吉林小区  SA22015  神州华奥  吉林     展厅    1
# 1635  2020-10-04  东北区  吉林小区  SA22015  神州华奥  吉林     展厅    2
# 2163  2020-10-05  东北区  吉林小区  SA22015  神州华奥  吉林     展厅    2
# 2686  2020-10-06  东北区  吉林小区  SA22015  神州华奥  吉林     展厅    3
# 3210  2020-10-07  东北区  吉林小区  SA22015  神州华奥  吉林     展厅    1
# 3743  2020-10-08  东北区  吉林小区  SA22015  神州华奥  吉林     展厅    1
# 5226  2020-10-11  东北区  吉林小区  SA22015  神州华奥  吉林     展厅    1
# 5808  2020-10-12  东北区  吉林小区  SA22015  神州华奥  吉林     展厅    1
# 7705  2020-10-16  东北区  吉林小区  SA22015  神州华奥  吉林     展厅    1
# 11859 2020-10-24  东北区  吉林小区  SA22015  神州华奥  吉林     展厅    2
# 15913 2020-10-31  东北区  吉林小区  SA22015  神州华奥  吉林     展厅    1

# %%
start = 0
for idx, row in dealerUnique.iterrows():
    print(idx, row['经销商代码'], row['客户来源更新'])
    start = genNewData(row['经销商代码'], row['客户来源更新'], start)
    print(start)
# Out:
# 0 SA15016 展厅
# 21
# 1 SA22002 展厅
# 83
# 2 SA22002 线上
# 122
# 3 SA22015 展厅
# 140
# 4 SA22015 线上
# 148
# 5 SA22009 展厅
# 153
# 6 SA22009 线上
# 161
# 7 SA22010 线上
# 163
# 8 SA22001 展厅
# 164
# 9 SA22001 线上
# 176
# 10 SA22003 展厅
# 221
# 11 SA22003 线上
# 246
# 12 SA22008 展厅
# 253
# 13 SA22008 线上
# 327
# 14 SA22012 展厅
# 338
# 15 SA22012 线上
# 378
# 16 SA22016 展厅
# 395
# 17 SA22016 线上
# 427
# 18 SA21018 展厅
# 470
# 19 SA21018 线上
# 484
# 20 SA21002 展厅
# 527
# 21 SA21002 线上
# 860
# 22 SA21006 展厅
# 893
# 23 SA21006 线上
# 927
# 24 SA21013 展厅
# 962
# 25 SA21013 线上
# 976
# 26 SA21016 展厅
# 1042
# 27 SA21016 线上
# 1049
# 28 SA21024 展厅
# 1303
# 29 SA21024 线上
# 1324
# 30 SA21027 展厅
# 1328
# 31 SA21027 线上
# 1398
# 32 SA21020 展厅
# 1408
# 33 SA21020 线上
# 1412
# 34 SA15009 展厅
# 1414
# 35 SA15009 线上
# 1425
# 36 SA21026 展厅
# 1442
# 37 SA21026 线上
# 1482
# 38 SA21005 展厅
# 1492
# 39 SA21005 线上
# 1508
# 40 SA21015 线上
# 1587
# 41 SA21009 展厅
# 1631
# 42 SA21009 线上
# 1658
# 43 SA21010 展厅
# 1719
# 44 SA21010 线上
# 1735
# 45 SA21012 展厅
# 1779
# 46 SA21012 线上
# 1838
# 47 SA21023 展厅
# 1859
# 48 SA21023 线上
# 1995
# 49 SA21021 展厅
# 2119
# 50 SA21021 线上
# 2133
# 51 SA21007 线上
# 2139
# 52 SA21014 展厅
# 2141
# 53 SA21014 线上
# 2213
# 54 SA21025 展厅
# 2216
# 55 SA21025 线上
# 2218
# 56 SA21011 展厅
# 2277
# 57 SA21011 线上
# 2303
# 58 SA21022 展厅
# 2339
# 59 SA21022 线上
# 2352
# 60 SA37014 展厅
# 2358
# 61 SA37014 线上
# 2435
# 62 SA37018 展厅
# 2541
# 63 SA37018 线上
# 2545
# 64 SA37017 展厅
# 2579
# 65 SA37017 线上
# 2678
# 66 SA37043 展厅
# 2795
# 67 SA37043 线上
# 2842
# 68 SA37517 线上
# 2847
# 69 SA37010 展厅
# 3003
# 70 SA37010 线上
# 3126
# 71 SA37021 展厅
# 3151
# 72 SA37021 线上
# 3209
# 73 SA37037 展厅
# 3308
# 74 SA37037 线上
# 3478
# 75 SA37041 展厅
# 3481
# 76 SA37041 线上
# 3482
# 77 SA37052 展厅
# 3497
# 78 SA37052 线上
# 3498
# 79 SA37053 展厅
# 3550
# 80 SA37053 线上
# 3553
# 81 SA37013 展厅
# 3558
# 82 SA37013 线上
# 3652
# 83 SA37042 展厅
# 3655
# 84 SA37042 线上
# 3688
# 85 SA37505 展厅
# 3701
# 86 SA37505 线上
# 3726
# 87 SA37007 展厅
# 3779
# 88 SA37007 线上
# 3819
# 89 SA37026 展厅
# 3822
# 90 SA37026 线上
# 3882
# 91 SA37025 展厅
# 3886
# 92 SA37025 线上
# 3935
# 93 SA37005 展厅
# 3964
# 94 SA37005 线上
# 3976
# 95 SA37023 展厅
# 4107
# 96 SA37023 线上
# 4327
# 97 SA37028 展厅
# 4382
# 98 SA37028 线上
# 4416
# 99 SA37055 展厅
# 4495
# 100 SA37055 线上
# 4655
# 101 SA37040 线上
# 4749
# 102 SA37050 展厅
# 4797
# 103 SA37056 展厅
# 4807
# 104 SA37058 展厅
# 4809
# 105 SA37058 线上
# 4826
# 106 SA37057 展厅
# 4942
# 107 SA37057 线上
# 4977
# 108 SA37011 展厅
# 4990
# 109 SA37011 线上
# 5030
# 110 SA37030 展厅
# 5053
# 111 SA37030 线上
# 5097
# 112 SA37033 展厅
# 5180
# 113 SA37033 线上
# 5217
# 114 SA37046 展厅
# 5262
# 115 SA37046 线上
# 5289
# 116 SA37029 展厅
# 5405
# 117 SA37029 线上
# 5522
# 118 SA37015 展厅
# 5577
# 119 SA37015 线上
# 5764
# 120 SA37016 展厅
# 5843
# 121 SA37016 线上
# 5916
# 122 SA37020 展厅
# 6147
# 123 SA37020 线上
# 6329
# 124 SA37045 展厅
# 6363
# 125 SA37045 线上
# 6688
# 126 SA37047 展厅
# 6736
# 127 SA37047 线上
# 6789
# 128 SA37049 展厅
# 6823
# 129 SA37049 线上
# 6825
# 130 SA37022 展厅
# 6866
# 131 SA37022 线上
# 6938
# 132 SA37031 展厅
# 7000
# 133 SA37031 线上
# 7002
# 134 SA23008 展厅
# 7122
# 135 SA23008 线上
# 7126
# 136 SA15011 展厅
# 7765
# 137 SA15011 线上
# 7785
# 138 SA23001 展厅
# 7826
# 139 SA23001 线上
# 7871
# 140 SA23002 线上
# 7936
# 141 SA23004 展厅
# 7947
# 142 SA23004 线上
# 7992
# 143 SA23005 展厅
# 8012
# 144 SA23005 线上
# 8210
# 145 SA23010 展厅
# 8305
# 146 SA23010 线上
# 8359
# 147 SA23003 线上
# 8393
# 148 SA23007 线上
# 8396
# 149 SA23012 展厅
# 8397
# 150 SA23012 线上
# 8400
# 151 SA23006 线上
# 8414
# 152 SA33025 展厅
# 8470
# 153 SA33025 线上
# 8715
# 154 SA33015 展厅
# 8817
# 155 SA33015 线上
# 8839
# 156 SA33028 展厅
# 8851
# 157 SA33028 线上
# 8867
# 158 SA33047 展厅
# 8878
# 159 SA33047 线上
# 8897
# 160 SA33066 展厅
# 8954
# 161 SA33066 线上
# 9108
# 162 SA33075 展厅
# 9115
# 163 SA33075 线上
# 9128
# 164 SA33076 展厅
# 9160
# 165 SA33076 线上
# 9243
# 166 SA33008 展厅
# 9299
# 167 SA33008 线上
# 9507
# 168 SA33022 展厅
# 9599
# 169 SA33022 线上
# 9800
# 170 SA33052 展厅
# 9896
# 171 SA33052 线上
# 9908
# 172 SA33059 线上
# 9920
# 173 SA33011 展厅
# 10032
# 174 SA33011 线上
# 10152
# 175 SA33043 展厅
# 10201
# 176 SA33043 线上
# 10267
# 177 SA33048 展厅
# 10317
# 178 SA33048 线上
# 10355
# 179 SA33002 展厅
# 10361
# 180 SA33002 线上
# 10555
# 181 SA33016 展厅
# 10684
# 182 SA33016 线上
# 10757
# 183 SA33019 展厅
# 10946
# 184 SA33019 线上
# 11070
# 185 SA33024 展厅
# 11074
# 186 SA33024 线上
# 11100
# 187 SA33033 展厅
# 11200
# 188 SA33033 线上
# 11268
# 189 SA33040 展厅
# 11271
# 190 SA33040 线上
# 11290
# 191 SA33063 展厅
# 11338
# 192 SA33063 线上
# 11357
# 193 SA33064 展厅
# 11358
# 194 SA33064 线上
# 11371
# 195 SA33070 展厅
# 11394
# 196 SA33070 线上
# 11451
# 197 SA33079 展厅
# 11512
# 198 SA33079 线上
# 11575
# 199 SA33080 展厅
# 11607
# 200 SA33080 线上
# 11611
# 201 SA33001 展厅
# 11622
# 202 SA33001 线上
# 11657
# 203 SA33006 展厅
# 11658
# 204 SA33006 线上
# 11720
# 205 SA33012 展厅
# 11793
# 206 SA33012 线上
# 11838
# 207 SA33030 展厅
# 11935
# 208 SA33030 线上
# 12095
# 209 SA33034 展厅
# 12103
# 210 SA33034 线上
# 12146
# 211 SA33038 展厅
# 12165
# 212 SA33038 线上
# 12211
# 213 SA33050 展厅
# 12308
# 214 SA33050 线上
# 12381
# 215 SA33058 展厅
# 12437
# 216 SA33058 线上
# 12517
# 217 SA33071 展厅
# 12559
# 218 SA33071 线上
# 12693
# 219 SA33072 展厅
# 12779
# 220 SA33072 线上
# 12847
# 221 SA33077 展厅
# 12962
# 222 SA33077 线上
# 13050
# 223 SA33003 展厅
# 13268
# 224 SA33003 线上
# 13298
# 225 SA33020 展厅
# 13362
# 226 SA33020 线上
# 13545
# 227 SA33021 展厅
# 13554
# 228 SA33021 线上
# 13633
# 229 SA33037 线上
# 13758
# 230 SA33044 展厅
# 13770
# 231 SA33049 展厅
# 13775
# 232 SA33049 线上
# 13780
# 233 SA33056 展厅
# 13788
# 234 SA33056 线上
# 13865
# 235 SA33065 展厅
# 13902
# 236 SA33065 线上
# 13989
# 237 SA33007 展厅
# 14016
# 238 SA33007 线上
# 14116
# 239 SA33017 展厅
# 14293
# 240 SA33017 线上
# 14507
# 241 SA33031 展厅
# 14560
# 242 SA33031 线上
# 14577
# 243 SA33057 展厅
# 14605
# 244 SA33057 线上
# 14614
# 245 SA33062 展厅
# 14628
# 246 SA33062 线上
# 14696
# 247 SA33042 展厅
# 14773
# 248 SA33042 线上
# 14786
# 249 SA33032 展厅
# 14803
# 250 SA33032 线上
# 14809
# 251 SA33005 展厅
# 14881
# 252 SA33005 线上
# 14925
# 253 SA33009 展厅
# 14953
# 254 SA33009 线上
# 14980
# 255 SA33026 展厅
# 14991
# 256 SA33026 线上
# 15014
# 257 SA33035 展厅
# 15021
# 258 SA33035 线上
# 15181
# 259 SA33036 展厅
# 15188
# 260 SA33036 线上
# 15223
# 261 SA33045 展厅
# 15296
# 262 SA33045 线上
# 15467
# 263 SA35008 展厅
# 15555
# 264 SA35008 线上
# 15649
# 265 SA35508 展厅
# 15661
# 266 SA35013 线上
# 15668
# 267 SA35002 展厅
# 15690
# 268 SA35002 线上
# 15791
# 269 SA35009 展厅
# 15828
# 270 SA35009 线上
# 15889
# 271 SA35016 展厅
# 15926
# 272 SA35016 线上
# 15976
# 273 SA35020 展厅
# 16010
# 274 SA35020 线上
# 16079
# 275 SA35015 展厅
# 16110
# 276 SA35015 线上
# 16375
# 277 SA35023 展厅
# 16394
# 278 SA35023 线上
# 16421
# 279 SA35001 展厅
# 16432
# 280 SA35001 线上
# 16440
# 281 SA35018 展厅
# 16565
# 282 SA35018 线上
# 16933
# 283 SA35021 展厅
# 16960
# 284 SA35021 线上
# 17042
# 285 SA35022 展厅
# 17229
# 286 SA35022 线上
# 17316
# 287 SA35004 展厅
# 17366
# 288 SA35004 线上
# 17422
# 289 SA35005 展厅
# 17776
# 290 SA35005 线上
# 17859
# 291 SA35010 展厅
# 17889
# 292 SA35010 线上
# 17931
# 293 SA35012 展厅
# 18018
# 294 SA35012 线上
# 18024
# 295 SA35011 展厅
# 18203
# 296 SA35011 线上
# 18297
# 297 SA32003 展厅
# 18311
# 298 SA32003 线上
# 18398
# 299 SA32004 展厅
# 18584
# 300 SA32004 线上
# 18634
# 301 SA32012 展厅
# 19568
# 302 SA32012 线上
# 19687
# 303 SA32024 展厅
# 19732
# 304 SA32024 线上
# 19800
# 305 SA32047 展厅
# 19802
# 306 SA32047 线上
# 19854
# 307 SA32049 展厅
# 19856
# 308 SA32049 线上
# 19882
# 309 SA32070 展厅
# 19895
# 310 SA32070 线上
# 19898
# 311 SA32076 展厅
# 19911
# 312 SA32076 线上
# 19945
# 313 SA32078 展厅
# 20035
# 314 SA32078 线上
# 20038
# 315 SA32006 展厅
# 20323
# 316 SA32006 线上
# 20406
# 317 SA32020 展厅
# 20652
# 318 SA32020 线上
# 20876
# 319 SA32044 展厅
# 20948
# 320 SA32044 线上
# 21003
# 321 SA32063 展厅
# 21209
# 322 SA32063 线上
# 21230
# 323 SA32543 展厅
# 21257
# 324 SA32543 线上
# 21292
# 325 SA32022 展厅
# 21516
# 326 SA32022 线上
# 21543
# 327 SA32043 展厅
# 21751
# 328 SA32043 线上
# 21798
# 329 SA32058 展厅
# 21861
# 330 SA32058 线上
# 21875
# 331 SA32061 展厅
# 21891
# 332 SA32061 线上
# 21897
# 333 SA32005 展厅
# 21913
# 334 SA32005 线上
# 21972
# 335 SA32027 展厅
# 22108
# 336 SA32027 线上
# 22110
# 337 SA32067 展厅
# 22235
# 338 SA32067 线上
# 22265
# 339 SA32068 展厅
# 22290
# 340 SA32068 线上
# 22341
# 341 SA32077 展厅
# 22373
# 342 SA32079 展厅
# 22440
# 343 SA32079 线上
# 22441
# 344 SA32037 展厅
# 22521
# 345 SA32037 线上
# 22559
# 346 SA32069 展厅
# 22864
# 347 SA32069 线上
# 22881
# 348 SA32011 展厅
# 23000
# 349 SA32011 线上
# 23043
# 350 SA32511 展厅
# 23049
# 351 SA32072 展厅
# 23187
# 352 SA32072 线上
# 23286
# 353 SA32009 展厅
# 23297
# 354 SA32009 线上
# 23313
# 355 SA32029 展厅
# 23381
# 356 SA32029 线上
# 23506
# 357 SA32080 展厅
# 23521
# 358 SA32023 展厅
# 23799
# 359 SA32023 线上
# 24041
# 360 SA32062 展厅
# 24088
# 361 SA32062 线上
# 24130
# 362 SA32052 展厅
# 24142
# 363 SA32052 线上
# 24151
# 364 SA32053 展厅
# 24152
# 365 SA32053 线上
# 24247
# 366 SA32048 线上
# 24338
# 367 SA32002 展厅
# 24737
# 368 SA32002 线上
# 24747
# 369 SA32018 展厅
# 24759
# 370 SA32018 线上
# 24784
# 371 SA32021 展厅
# 24901
# 372 SA32021 线上
# 24950
# 373 SA32032 展厅
# 24971
# 374 SA32032 线上
# 24987
# 375 SA32042 展厅
# 25016
# 376 SA32042 线上
# 25024
# 377 SA32045 展厅
# 25043
# 378 SA32045 线上
# 25045
# 379 SA32050 展厅
# 25116
# 380 SA32050 线上
# 25233
# 381 SA32051 展厅
# 25372
# 382 SA32051 线上
# 25438
# 383 SA32054 展厅
# 25620
# 384 SA32054 线上
# 25666
# 385 SA31001 展厅
# 25772
# 386 SA31001 线上
# 25858
# 387 SA31003 展厅
# 25865
# 388 SA31003 线上
# 25918
# 389 SA31010 展厅
# 25924
# 390 SA31015 展厅
# 25955
# 391 SA31015 线上
# 25958
# 392 SA31018 展厅
# 26055
# 393 SA31018 线上
# 26138
# 394 SA31022 展厅
# 26565
# 395 SA31022 线上
# 26640
# 396 SA31025 展厅
# 26650
# 397 SA31025 线上
# 26746
# 398 SA31029 展厅
# 26748
# 399 SA31029 线上
# 26810
# 400 SA31032 展厅
# 26811
# 401 SA31032 线上
# 26856
# 402 SA31002 展厅
# 26959
# 403 SA31002 线上
# 27185
# 404 SA31004 展厅
# 27186
# 405 SA31004 线上
# 27204
# 406 SA31008 展厅
# 27205
# 407 SA31008 线上
# 27264
# 408 SA31009 展厅
# 27296
# 409 SA31009 线上
# 27337
# 410 SA31016 展厅
# 28003
# 411 SA31016 线上
# 28031
# 412 SA31017 展厅
# 28070
# 413 SA31017 线上
# 28073
# 414 SA31020 展厅
# 28086
# 415 SA31020 线上
# 28090
# 416 SA31023 展厅
# 28130
# 417 SA31023 线上
# 28143
# 418 SA31033 展厅
# 28148
# 419 SA31523 展厅
# 28163
# 420 SA31523 线上
# 28167
# 421 SA34016 展厅
# 28312
# 422 SA34016 线上
# 28323
# 423 SA34001 展厅
# 28495
# 424 SA34001 线上
# 28572
# 425 SA34003 展厅
# 28573
# 426 SA34003 线上
# 28575
# 427 SA34004 展厅
# 28584
# 428 SA34004 线上
# 28601
# 429 SA34009 展厅
# 28617
# 430 SA34009 线上
# 28632
# 431 SA34019 展厅
# 28677
# 432 SA34019 线上
# 28715
# 433 SA34021 展厅
# 28717
# 434 SA34021 线上
# 28723
# 435 SA34017 展厅
# 28817
# 436 SA34017 线上
# 28828
# 437 SA34012 展厅
# 28835
# 438 SA34012 线上
# 28842
# 439 SA34025 展厅
# 28854
# 440 SA34006 展厅
# 28864
# 441 SA34006 线上
# 28893
# 442 SA34011 展厅
# 28909
# 443 SA34011 线上
# 28924
# 444 SA34010 展厅
# 28932
# 445 SA34010 线上
# 28944
# 446 SA34002 展厅
# 29021
# 447 SA34002 线上
# 29038
# 448 SA34007 展厅
# 29039
# 449 SA34007 线上
# 29048
# 450 SA34707 展厅
# 29050
# 451 SA34022 展厅
# 29061
# 452 SA34022 线上
# 29065
# 453 SA34607 展厅
# 29067
# 454 SA34607 线上
# 29077
# 455 SA34013 展厅
# 29085
# 456 SA34023 展厅
# 29092
# 457 SA34023 线上
# 29099
# 458 SA34015 展厅
# 29163
# 459 SA34015 线上
# 29240
# 460 SA34005 线上
# 29365
# 461 SA34507 展厅
# 29414
# 462 SA34507 线上
# 29418
# 463 SA32508 展厅
# 29419
# 464 SA32508 线上
# 29422
# 465 SA32065 展厅
# 29432
# 466 SA32065 线上
# 29434
# 467 SA32008 展厅
# 29449
# 468 SA32008 线上
# 29453
# 469 SA32010 展厅
# 29654
# 470 SA32010 线上
# 29750
# 471 SA32015 展厅
# 29867
# 472 SA32015 线上
# 29939
# 473 SA32016 展厅
# 29969
# 474 SA32017 展厅
# 29999
# 475 SA32017 线上
# 30032
# 476 SA32028 展厅
# 30229
# 477 SA32028 线上
# 30294
# 478 SA32033 展厅
# 30317
# 479 SA32033 线上
# 30326
# 480 SA32035 展厅
# 30392
# 481 SA32035 线上
# 30406
# 482 SA32036 展厅
# 30537
# 483 SA32036 线上
# 30555
# 484 SA32041 展厅
# 30575
# 485 SA32041 线上
# 30587
# 486 SA32057 展厅
# 30601
# 487 SA32057 线上
# 30639
# 488 SA32060 展厅
# 30685
# 489 SA32060 线上
# 30700
# 490 SA41016 展厅
# 30828
# 491 SA41016 线上
# 30924
# 492 SA41025 展厅
# 31016
# 493 SA41025 线上
# 31038
# 494 SA41026 展厅
# 31048
# 495 SA41026 线上
# 31065
# 496 SA41009 展厅
# 31160
# 497 SA41009 线上
# 31246
# 498 SA41017 展厅
# 31275
# 499 SA41017 线上
# 31289
# 500 SA41013 展厅
# 31314
# 501 SA41013 线上
# 31348
# 502 SA41002 展厅
# 31745
# 503 SA41002 线上
# 32029
# 504 SA41004 展厅
# 32140
# 505 SA41004 线上
# 32211
# 506 SA41023 展厅
# 32766
# 507 SA41023 线上
# 32921
# 508 SA41027 展厅
# 32922
# 509 SA41030 展厅
# 32934
# 510 SA41030 线上
# 32997
# 511 SA41031 展厅
# 32998
# 512 SA41031 线上
# 33036
# 513 SA41014 展厅
# 33203
# 514 SA41014 线上
# 33346
# 515 SA41010 展厅
# 33361
# 516 SA41010 线上
# 33371
# 517 SA41029 展厅
# 33407
# 518 SA41029 线上
# 33419
# 519 SA41032 展厅
# 33483
# 520 SA41032 线上
# 33534
# 521 SA41008 展厅
# 33547
# 522 SA41008 线上
# 33560
# 523 SA41005 展厅
# 33581
# 524 SA41005 线上
# 33615
# 525 SA41505 展厅
# 33625
# 526 SA41505 线上
# 33627
# 527 SA41033 展厅
# 33650
# 528 SA41033 线上
# 33713
# 529 SA41020 展厅
# 33747
# 530 SA41020 线上
# 33757
# 531 SA41018 展厅
# 33871
# 532 SA41018 线上
# 33893
# 533 SA13002 展厅
# 33914
# 534 SA13002 线上
# 33934
# 535 SA13015 展厅
# 33972
# 536 SA13015 线上
# 33992
# 537 SA13003 展厅
# 34056
# 538 SA13003 线上
# 34073
# 539 SA13008 展厅
# 34083
# 540 SA13008 线上
# 34103
# 541 SA13009 线上
# 34149
# 542 SA13017 展厅
# 34211
# 543 SA13017 线上
# 34265
# 544 SA13020 展厅
# 34310
# 545 SA13020 线上
# 34412
# 546 SA13010 展厅
# 34527
# 547 SA13010 线上
# 34569
# 548 SA13006 线上
# 34589
# 549 SA13004 展厅
# 34590
# 550 SA13004 线上
# 34607
# 551 SA13019 展厅
# 34652
# 552 SA13019 线上
# 34724
# 553 SA13001 展厅
# 34969
# 554 SA13001 线上
# 35125
# 555 SA13007 展厅
# 35127
# 556 SA13007 线上
# 35138
# 557 SA13011 展厅
# 35182
# 558 SA13011 线上
# 35357
# 559 SA13013 展厅
# 35444
# 560 SA13013 线上
# 35634
# 561 SA13022 展厅
# 35661
# 562 SA13022 线上
# 35685
# 563 SA13012 展厅
# 35687
# 564 SA13012 线上
# 35724
# 565 SA13021 展厅
# 36069
# 566 SA13021 线上
# 36478
# 567 SA13005 展厅
# 36486
# 568 SA13005 线上
# 36498
# 569 SA13018 展厅
# 36499
# 570 SA13018 线上
# 36508
# 571 SA15007 展厅
# 36530
# 572 SA15002 展厅
# 36547
# 573 SA15002 线上
# 36562
# 574 SA15010 展厅
# 36603
# 575 SA15010 线上
# 36633
# 576 SA15001 线上
# 36677
# 577 SA15006 展厅
# 36684
# 578 SA15006 线上
# 36723
# 579 SA15013 展厅
# 36726
# 580 SA15013 线上
# 36730
# 581 SA15012 展厅
# 36737
# 582 SA15012 线上
# 36738
# 583 SA15005 展厅
# 37123
# 584 SA15005 线上
# 37167
# 585 SA15003 展厅
# 37173
# 586 SA15003 线上
# 37200
# 587 SA15008 展厅
# 37202
# 588 SA15008 线上
# 37211
# 589 SA15015 展厅
# 37231
# 590 SA15015 线上
# 37236
# 591 SA11003 展厅
# 37322
# 592 SA11003 线上
# 37340
# 593 SA11016 展厅
# 37350
# 594 SA11016 线上
# 37392
# 595 SA11022 展厅
# 37481
# 596 SA11022 线上
# 37503
# 597 SA11031 展厅
# 37517
# 598 SA11031 线上
# 37539
# 599 SA11033 展厅
# 37600
# 600 SA11033 线上
# 37709
# 601 SA11036 展厅
# 37741
# 602 SA11036 线上
# 37745
# 603 SA11038 展厅
# 37751
# 604 SA11038 线上
# 37753
# 605 SA11043 展厅
# 37757
# 606 SA11043 线上
# 37761
# 607 SA11011 展厅
# 37767
# 608 SA11011 线上
# 37789
# 609 SA11014 展厅
# 37806
# 610 SA11014 线上
# 37859
# 611 SA11026 展厅
# 37944
# 612 SA11026 线上
# 37947
# 613 SA11035 展厅
# 38020
# 614 SA11035 线上
# 38021
# 615 SA11041 展厅
# 38037
# 616 SA11041 线上
# 38045
# 617 SA11042 展厅
# 38057
# 618 SA11042 线上
# 38070
# 619 SA11045 展厅
# 38083
# 620 SA11045 线上
# 38132
# 621 SA11002 展厅
# 38154
# 622 SA11002 线上
# 38331
# 623 SA11017 展厅
# 38337
# 624 SA11017 线上
# 38497
# 625 SA11019 展厅
# 38600
# 626 SA11019 线上
# 38632
# 627 SA11027 展厅
# 38649
# 628 SA11027 线上
# 38712
# 629 SA11030 展厅
# 38779
# 630 SA11030 线上
# 38790
# 631 SA11040 展厅
# 38834
# 632 SA11040 线上
# 38918
# 633 SA11046 展厅
# 38930
# 634 SA11046 线上
# 38989
# 635 SA11050 线上
# 39006
# 636 SA12001 展厅
# 39079
# 637 SA12001 线上
# 39092
# 638 SA12002 展厅
# 39141
# 639 SA12002 线上
# 39207
# 640 SA12004 展厅
# 39292
# 641 SA12004 线上
# 39396
# 642 SA12005 展厅
# 39580
# 643 SA12005 线上
# 39659
# 644 SA12006 线上
# 39699
# 645 SA12008 展厅
# 39800
# 646 SA12008 线上
# 39803
# 647 SA12011 展厅
# 39845
# 648 SA12011 线上
# 39859
# 649 SA12013 展厅
# 39870
# 650 SA12013 线上
# 39871
# 651 SA14006 展厅
# 39888
# 652 SA14006 线上
# 39898
# 653 SA14010 展厅
# 39905
# 654 SA14010 线上
# 39908
# 655 SA14019 展厅
# 39970
# 656 SA14019 线上
# 40022
# 657 SA14001 展厅
# 40053
# 658 SA14001 线上
# 40079
# 659 SA14002 展厅
# 40317
# 660 SA14002 线上
# 40328
# 661 SA14008 展厅
# 40396
# 662 SA14008 线上
# 40434
# 663 SA14011 展厅
# 40450
# 664 SA14011 线上
# 40470
# 665 SA14016 展厅
# 40471
# 666 SA14013 展厅
# 40517
# 667 SA14013 线上
# 40531
# 668 SA14018 展厅
# 40534
# 669 SA14018 线上
# 40538
# 670 SA14017 展厅
# 40660
# 671 SA14017 线上
# 40668
# 672 SA14007 展厅
# 40722
# 673 SA14007 线上
# 40761
# 674 SA14012 展厅
# 40767
# 675 SA44001 展厅
# 40784
# 676 SA44001 线上
# 40959
# 677 SA44002 展厅
# 41006
# 678 SA44002 线上
# 41265
# 679 SA44003 展厅
# 41761
# 680 SA44003 线上
# 41885
# 681 SA44019 展厅
# 41909
# 682 SA44019 线上
# 41975
# 683 SA44027 展厅
# 42132
# 684 SA44027 线上
# 42192
# 685 SA44029 展厅
# 42195
# 686 SA44029 线上
# 42196
# 687 SA44033 展厅
# 42243
# 688 SA44033 线上
# 42248
# 689 SA44037 展厅
# 42313
# 690 SA44037 线上
# 42344
# 691 SA44043 展厅
# 42349
# 692 SA44043 线上
# 42373
# 693 SA44044 展厅
# 42439
# 694 SA44044 线上
# 42519
# 695 SA44059 展厅
# 42580
# 696 SA44059 线上
# 42592
# 697 SA44075 展厅
# 42622
# 698 SA44075 线上
# 42667
# 699 SA46008 展厅
# 42701
# 700 SA46008 线上
# 42708
# 701 SA45011 展厅
# 42714
# 702 SA45011 线上
# 42715
# 703 SA45002 展厅
# 42729
# 704 SA45002 线上
# 42851
# 705 SA45005 展厅
# 43000
# 706 SA45005 线上
# 43099
# 707 SA45007 展厅
# 43315
# 708 SA45007 线上
# 43425
# 709 SA45008 展厅
# 43427
# 710 SA45008 线上
# 43428
# 711 SA45009 展厅
# 43432
# 712 SA45003 展厅
# 43473
# 713 SA45003 线上
# 43559
# 714 SA45006 展厅
# 43564
# 715 SA45006 线上
# 43622
# 716 SA46003 展厅
# 43655
# 717 SA46003 线上
# 43697
# 718 SA46005 展厅
# 43779
# 719 SA46005 线上
# 43804
# 720 SA42005 展厅
# 43870
# 721 SA42005 线上
# 43888
# 722 SA42010 展厅
# 44111
# 723 SA42010 线上
# 44119
# 724 SA42011 展厅
# 44122
# 725 SA42011 线上
# 44124
# 726 SA42013 线上
# 44388
# 727 SA42014 展厅
# 44780
# 728 SA42014 线上
# 44904
# 729 SA42020 展厅
# 45377
# 730 SA42020 线上
# 45415
# 731 SA36017 展厅
# 45448
# 732 SA36017 线上
# 45850
# 733 SA36009 线上
# 45864
# 734 SA36001 展厅
# 45865
# 735 SA36006 展厅
# 45936
# 736 SA36006 线上
# 46214
# 737 SA36007 展厅
# 46229
# 738 SA36007 线上
# 46973
# 739 SA36013 展厅
# 46993
# 740 SA36013 线上
# 47033
# 741 SA36008 展厅
# 47034
# 742 SA36008 线上
# 47198
# 743 SA36015 展厅
# 47200
# 744 SA36015 线上
# 47353
# 745 SA36012 展厅
# 47379
# 746 SA36012 线上
# 47415
# 747 SA36016 展厅
# 47509
# 748 SA36016 线上
# 47543
# 749 SA36003 展厅
# 47606
# 750 SA36003 线上
# 47657
# 751 SA36503 展厅
# 47660
# 752 SA36503 线上
# 47661
# 753 SA44006 展厅
# 47676
# 754 SA44006 线上
# 47739
# 755 SA44011 展厅
# 47790
# 756 SA44011 线上
# 47828
# 757 SA44012 展厅
# 47956
# 758 SA44012 线上
# 48005
# 759 SA44018 展厅
# 48238
# 760 SA44018 线上
# 48377
# 761 SA44028 展厅
# 48649
# 762 SA44028 线上
# 48859
# 763 SA44031 展厅
# 49189
# 764 SA44031 线上
# 49322
# 765 SA44036 展厅
# 49372
# 766 SA44036 线上
# 49379
# 767 SA44050 展厅
# 49437
# 768 SA44050 线上
# 49463
# 769 SA44051 展厅
# 49653
# 770 SA44051 线上
# 49750
# 771 SA44058 线上
# 49808
# 772 SA44060 线上
# 49814
# 773 SA44061 展厅
# 49842
# 774 SA44061 线上
# 50001
# 775 SA44062 展厅
# 50152
# 776 SA44062 线上
# 50182
# 777 SA42009 展厅
# 50334
# 778 SA42009 线上
# 50393
# 779 SA42004 展厅
# 50450
# 780 SA42004 线上
# 50510
# 781 SA42017 展厅
# 50513
# 782 SA42017 线上
# 50904
# 783 SA42016 展厅
# 50906
# 784 SA42016 线上
# 50950
# 785 SA42012 展厅
# 50973
# 786 SA42012 线上
# 50989
# 787 SA42018 线上
# 50995
# 788 SA42006 展厅
# 50999
# 789 SA42006 线上
# 51043
# 790 SA42021 展厅
# 51048
# 791 SA42019 展厅
# 51049
# 792 SA42019 线上
# 51054
# 793 SA42015 展厅
# 51094
# 794 SA42015 线上
# 51097
# 795 SA42008 展厅
# 51259
# 796 SA42008 线上
# 51285
# 797 SA43017 展厅
# 51342
# 798 SA43017 线上
# 51351
# 799 SA43016 展厅
# 51358
# 800 SA43016 线上
# 51379
# 801 SA43015 展厅
# 51471
# 802 SA43015 线上
# 51576
# 803 SA43013 展厅
# 51603
# 804 SA43013 线上
# 51667
# 805 SA43008 展厅
# 51714
# 806 SA43008 线上
# 51739
# 807 SA43011 展厅
# 51758
# 808 SA43011 线上
# 51769
# 809 SA43022 展厅
# 51787
# 810 SA43006 展厅
# 51794
# 811 SA43019 展厅
# 51911
# 812 SA43019 线上
# 51952
# 813 SA43007 展厅
# 52103
# 814 SA43007 线上
# 52158
# 815 SA44010 展厅
# 52223
# 816 SA44010 线上
# 52932
# 817 SA44017 展厅
# 52948
# 818 SA44017 线上
# 53179
# 819 SA44039 展厅
# 53190
# 820 SA44039 线上
# 53260
# 821 SA44049 展厅
# 53286
# 822 SA44049 线上
# 53407
# 823 SA44054 线上
# 53454
# 824 SA44055 展厅
# 53579
# 825 SA44055 线上
# 53738
# 826 SA44020 展厅
# 53965
# 827 SA44020 线上
# 54031
# 828 SA44067 展厅
# 54088
# 829 SA44067 线上
# 54094
# 830 SA44030 展厅
# 54191
# 831 SA44030 线上
# 54209
# 832 SA44009 展厅
# 54215
# 833 SA44009 线上
# 54247
# 834 SA44071 展厅
# 54263
# 835 SA44025 展厅
# 54265
# 836 SA44025 线上
# 54301
# 837 SA44016 展厅
# 54368
# 838 SA44016 线上
# 54563
# 839 SA44023 展厅
# 54599
# 840 SA44023 线上
# 54684
# 841 SA44042 展厅
# 54697
# 842 SA44042 线上
# 54822
# 843 SA44046 展厅
# 54824
# 844 SA44046 线上
# 54894
# 845 SA44035 展厅
# 54964
# 846 SA44035 线上
# 54971
# 847 SA44070 展厅
# 55045
# 848 SA44070 线上
# 55069
# 849 SA44066 线上
# 55087
# 850 SA44013 展厅
# 55100
# 851 SA44013 线上
# 55131
# 852 SA44045 展厅
# 55132
# 853 SA44045 线上
# 55212
# 854 SA44022 展厅
# 55390
# 855 SA44022 线上
# 55558
# 856 SA44041 展厅
# 55593
# 857 SA44041 线上
# 55603
# 858 SA44004 展厅
# 55646
# 859 SA44004 线上
# 55661
# 860 SA44040 展厅
# 55818
# 861 SA44040 线上
# 55862
# 862 SA44026 展厅
# 55904
# 863 SA44026 线上
# 56058
# 864 SA44064 展厅
# 56059
# 865 SA44064 线上
# 56090
# 866 SA43001 展厅
# 56194
# 867 SA43001 线上
# 56345
# 868 SA43003 展厅
# 56352
# 869 SA43003 线上
# 56407
# 870 SA43005 展厅
# 56462
# 871 SA43005 线上
# 56607
# 872 SA43009 展厅
# 56682
# 873 SA43009 线上
# 56727
# 874 SA43010 展厅
# 56766
# 875 SA43010 线上
# 56836
# 876 SA43012 展厅
# 56857
# 877 SA43012 线上
# 56971
# 878 SA43021 展厅
# 57038
# 879 SA53016 展厅
# 57075
# 880 SA53016 线上
# 57093
# 881 SA53001 展厅
# 57160
# 882 SA53001 线上
# 57184
# 883 SA53002 展厅
# 57477
# 884 SA53002 线上
# 57739
# 885 SA53005 展厅
# 57808
# 886 SA53005 线上
# 57824
# 887 SA53007 展厅
# 57859
# 888 SA53007 线上
# 57875
# 889 SA53012 线上
# 57964
# 890 SA53006 展厅
# 57971
# 891 SA53006 线上
# 57975
# 892 SA53011 展厅
# 57987
# 893 SA53011 线上
# 58018
# 894 SA53010 展厅
# 58019
# 895 SA53010 线上
# 58021
# 896 SA51008 展厅
# 58068
# 897 SA51008 线上
# 58107
# 898 SA51011 展厅
# 58215
# 899 SA51011 线上
# 58249
# 900 SA51018 线上
# 58250
# 901 SA51023 展厅
# 58251
# 902 SA51023 线上
# 58258
# 903 SA51015 展厅
# 58273
# 904 SA51015 线上
# 58275
# 905 SA51016 展厅
# 58281
# 906 SA51016 线上
# 58286
# 907 SA51017 展厅
# 58287
# 908 SA51017 线上
# 58358
# 909 SA51027 展厅
# 58362
# 910 SA51027 线上
# 58366
# 911 SA51004 展厅
# 58367
# 912 SA51004 线上
# 58373
# 913 SA51032 线上
# 58375
# 914 SA51021 展厅
# 58376
# 915 SA51021 线上
# 58383
# 916 SA51022 展厅
# 58386
# 917 SA51022 线上
# 58391
# 918 SA51001 展厅
# 58427
# 919 SA51001 线上
# 58459
# 920 SA51003 展厅
# 58472
# 921 SA51003 线上
# 58502
# 922 SA51005 展厅
# 58537
# 923 SA51005 线上
# 58585
# 924 SA51006 展厅
# 58586
# 925 SA51006 线上
# 58622
# 926 SA51009 展厅
# 58861
# 927 SA51009 线上
# 60151
# 928 SA51013 线上
# 60165
# 929 SA51014 展厅
# 60296
# 930 SA51014 线上
# 60399
# 931 SA51019 展厅
# 60406
# 932 SA51019 线上
# 60422
# 933 SA51020 展厅
# 60855
# 934 SA51020 线上
# 60990
# 935 SA51025 线上
# 61010
# 936 SA51030 展厅
# 61031
# 937 SA65001 展厅
# 61133
# 938 SA65001 线上
# 61280
# 939 SA65002 展厅
# 61305
# 940 SA65002 线上
# 61330
# 941 SA65601 展厅
# 61336
# 942 SA65501 展厅
# 61356
# 943 SA65501 线上
# 61357
# 944 SA63001 展厅
# 61359
# 945 SA63001 线上
# 61366
# 946 SA63002 展厅
# 61442
# 947 SA63002 线上
# 61516
# 948 SA65701 展厅
# 61566
# 949 SA62001 展厅
# 61818
# 950 SA62001 线上
# 62048
# 951 SA62002 展厅
# 62050
# 952 SA62002 线上
# 62068
# 953 SA62003 展厅
# 62260
# 954 SA62003 线上
# 62450
# 955 SA62005 展厅
# 62454
# 956 SA62005 线上
# 62593
# 957 SA62006 展厅
# 62646
# 958 SA62006 线上
# 62652
# 959 SA64001 展厅
# 62696
# 960 SA64001 线上
# 62708
# 961 SA64005 展厅
# 62710
# 962 SA64005 线上
# 62732
# 963 SA52007 展厅
# 62733
# 964 SA52007 线上
# 62864
# 965 SA52015 展厅
# 62866
# 966 SA52015 线上
# 62867
# 967 SA52009 展厅
# 62907
# 968 SA52009 线上
# 62909
# 969 SA52010 展厅
# 62997
# 970 SA52010 线上
# 63017
# 971 SA52008 展厅
# 63018
# 972 SA52008 线上
# 63050
# 973 SA52002 展厅
# 63102
# 974 SA52002 线上
# 63208
# 975 SA52003 展厅
# 63214
# 976 SA52003 线上
# 63410
# 977 SA52006 展厅
# 63411
# 978 SA52006 线上
# 63444
# 979 SA52005 展厅
# 63470
# 980 SA52005 线上
# 63524
# 981 SA52505 展厅
# 63541
# 982 SA52505 线上
# 63564
# 983 SA52011 展厅
# 63622
# 984 SA52011 线上
# 63688
# 985 SA52013 展厅
# 63689
# 986 SA52013 线上
# 63703
# 987 SA55002 展厅
# 63704
# 988 SA55002 线上
# 63718
# 989 SA55003 展厅
# 63754
# 990 SA55003 线上
# 63856
# 991 SA55005 展厅
# 63857
# 992 SA55005 线上
# 64064
# 993 SA55006 展厅
# 64072
# 994 SA55006 线上
# 64282
# 995 SA55007 展厅
# 64308
# 996 SA55007 线上
# 64380
# 997 SA55009 线上
# 64382
# 998 SA55010 展厅
# 64388
# 999 SA55010 线上
# 64501
# 1000 SA55011 展厅
# 64505
# 1001 SA55012 展厅
# 64544
# 1002 SA55012 线上
# 64585
# 1003 SA55013 展厅
# 64590
# 1004 SA55013 线上
# 64597
# 1005 SA61013 展厅
# 64631
# 1006 SA61013 线上
# 64643
# 1007 SA61017 展厅
# 64646
# 1008 SA61010 线上
# 64651
# 1009 SA61008 展厅
# 64735
# 1010 SA61008 线上
# 64761
# 1011 SA61005 展厅
# 64798
# 1012 SA61005 线上
# 64809
# 1013 SA61012 线上
# 64814
# 1014 SA61015 线上
# 64838
# 1015 SA61001 展厅
# 64944
# 1016 SA61001 线上
# 65176
# 1017 SA61003 展厅
# 65214
# 1018 SA61003 线上
# 65341
# 1019 SA61006 展厅
# 65408
# 1020 SA61006 线上
# 65429
# 1021 SA61007 展厅
# 65680
# 1022 SA61007 线上
# 65992
# 1023 SA61011 展厅
# 66097
# 1024 SA61011 线上
# 66149
# 1025 SA61016 展厅
# 66169
# 1026 SA61016 线上
# 66208
# 1027 SA61018 展厅
# 66218
# 1028 SA61018 线上
# 66239
# 1029 SA33515 线上
# 66240
# 1030 SA35508 线上
# 66244
# 1031 SA32080 线上
# 66253
# 1032 SA34025 线上
# 66254
# 1033 SA34707 线上
# 66255
# 1034 SA41021 线上
# 66449
# 1035 SA36001 线上
# 66451
# 1036 SA44071 线上
# 66457
# 1037 SA44063 线上
# 66474
# 1038 SA43021 线上
# 66486
# 1039 SA51030 线上
# 66497
# 1040 SA54001 线上
# 66503

# %%
a1 = dataMiss.groupby(['大区名称', '小区名称', '城市', '经销商代码', '客户来源更新', '车型new'])['潜客量'].sum().reset_index()

# %%
a2 = a1.merge(dataCOMPUTed, on=['大区名称', '小区名称', '城市', '经销商代码', '客户来源更新', '车型new'], suffixes=['_o', '_f'])

# %%
dataCOMPUTed.head()
# Out:
#   大区名称  小区名称   城市    经销商代码 客户来源更新   车型new  潜客量
# 0  东北区  吉林小区  兴安盟  SA15016     展厅      A3    1
# 1  东北区  吉林小区  兴安盟  SA15016     展厅  A4 FBU    1
# 2  东北区  吉林小区  兴安盟  SA15016     展厅     A4L    3
# 3  东北区  吉林小区  兴安盟  SA15016     展厅  A6 FBU    3
# 4  东北区  吉林小区  兴安盟  SA15016     展厅     A6L    6

# %%
dataMiss.groupby(['日期', '大区名称', '小区名称', '经销商代码', '经销商名称', '城市', '客户来源更新', '车型new']).sum().reset_index()
# Out:
#               日期 大区名称  小区名称    经销商代码    经销商名称  城市 客户来源更新   车型new  潜客量  大区
# 0     2020-10-01  东北区  吉林小区  SA22002     吉林神华  吉林     线上     Q5L    1   0
# 1     2020-10-01  东北区  吉林小区  SA22012     吉林国兴  长春     线上     A4L    1   0
# 2     2020-10-01  东北区  吉林小区  SA22012     吉林国兴  长春     线上     A6L    2   0
# 3     2020-10-01  东北区  吉林小区  SA22012     吉林国兴  长春     线上     Q2L    1   0
# 4     2020-10-01  东北区  吉林小区  SA22012     吉林国兴  长春     线上     Q5L    1   0
# 5     2020-10-01  东北区  吉林小区  SA22015     神州华奥  吉林     展厅     Q2L    1   0
# 6     2020-10-01  东北区  吉林小区  SA22015     神州华奥  吉林     展厅     Q5L    1   0
# 7     2020-10-01  东北区  吉林小区  SA22016   长春华阳奥通  长春     线上     A4L    1   0
# 8     2020-10-01  东北区  辽东小区  SA21002     辽宁奥通  沈阳     展厅     A4L    1   0
# 9     2020-10-01  东北区  辽东小区  SA21002     辽宁奥通  沈阳     线上     A4L    1   0
# 10    2020-10-01  东北区  辽东小区  SA21002     辽宁奥通  沈阳     线上     A6L    1   0
# 11    2020-10-01  东北区  辽东小区  SA21002     辽宁奥通  沈阳     线上     Q5L    1   0
# 12    2020-10-01  东北区  辽东小区  SA21002     辽宁奥通  沈阳     线上  others    1   0
# 13    2020-10-01  东北区  辽东小区  SA21006     辽宁鑫迪  沈阳     展厅     A8L    1   0
# 14    2020-10-01  东北区  辽东小区  SA21013     沈阳奥尊  沈阳     展厅     A4L    1   0
# 15    2020-10-01  东北区  辽东小区  SA21018   丹东惠华新业  丹东     展厅     A4L    1   0
# 16    2020-10-01  东北区  辽东小区  SA21018   丹东惠华新业  丹东     展厅  A6 FBU    1   0
# 17    2020-10-01  东北区  辽东小区  SA21018   丹东惠华新业  丹东     展厅     Q5L    1   0
# 18    2020-10-01  东北区  辽东小区  SA21018   丹东惠华新业  丹东     线上     A4L    1   0
# 19    2020-10-01  东北区  辽东小区  SA21018   丹东惠华新业  丹东     线上     A8L    2   0
# 20    2020-10-01  东北区  辽东小区  SA21018   丹东惠华新业  丹东     线上     Q5L    2   0
# 21    2020-10-01  东北区  辽东小区  SA21024   沈阳业乔龙业  沈阳     展厅     A4L    3   0
# 22    2020-10-01  东北区  辽东小区  SA21024   沈阳业乔龙业  沈阳     展厅     A6L    2   0
# 23    2020-10-01  东北区  辽东小区  SA21024   沈阳业乔龙业  沈阳     展厅     A8L    1   0
# 24    2020-10-01  东北区  辽东小区  SA21024   沈阳业乔龙业  沈阳     展厅     Q2L    2   0
# 25    2020-10-01  东北区  辽东小区  SA21024   沈阳业乔龙业  沈阳     展厅      Q3    1   0
# 26    2020-10-01  东北区  辽东小区  SA21024   沈阳业乔龙业  沈阳     展厅     Q5L    2   0
# 27    2020-10-01  东北区  辽东小区  SA21024   沈阳业乔龙业  沈阳     线上     A4L    1   0
# 28    2020-10-01  东北区  辽东小区  SA21024   沈阳业乔龙业  沈阳     线上     Q5L    1   0
# 29    2020-10-01  东北区  辽东小区  SA21026   铁岭业乔龙业  铁岭     展厅     A4L    1   0
# ...          ...  ...   ...      ...      ...  ..    ...     ...  ...  ..
# 42230 2020-10-31  西部区  陕西小区  SA61007  陕西新丰泰博奥  西安     展厅     Q5L    1   0
# 42231 2020-10-31  西部区  陕西小区  SA61007  陕西新丰泰博奥  西安     展厅  others    1   0
# 42232 2020-10-31  西部区  陕西小区  SA61007  陕西新丰泰博奥  西安     线上      A3    1   0
# 42233 2020-10-31  西部区  陕西小区  SA61007  陕西新丰泰博奥  西安     线上     A4L    5   0
# 42234 2020-10-31  西部区  陕西小区  SA61007  陕西新丰泰博奥  西安     线上  A6 FBU    1   0
# 42235 2020-10-31  西部区  陕西小区  SA61007  陕西新丰泰博奥  西安     线上     A6L    2   0
# 42236 2020-10-31  西部区  陕西小区  SA61007  陕西新丰泰博奥  西安     线上  others    1   0
# 42237 2020-10-31  西部区  陕西小区  SA61008  延安新丰泰博奥  延安     线上      Q3    1   0
# 42238 2020-10-31  西部区  陕西小区  SA61010    宝鸡德奥达  宝鸡     线上      A3    1   0
# 42239 2020-10-31  西部区  陕西小区  SA61011   西安恒信奥龙  西安     线上     A4L    1   0
# 42240 2020-10-31  西部区  陕西小区  SA61011   西安恒信奥龙  西安     线上     Q5L    1   0
# 42241 2020-10-31  西部区  陕西小区  SA61013     陕西联强  咸阳     展厅     A4L    1   0
# 42242 2020-10-31  西部区  陕西小区  SA61013     陕西联强  咸阳     展厅     A6L    5   0
# 42243 2020-10-31  西部区  陕西小区  SA61013     陕西联强  咸阳     展厅     Q2L    1   0
# 42244 2020-10-31  西部区  陕西小区  SA61013     陕西联强  咸阳     展厅      Q3    1   0
# 42245 2020-10-31  西部区  陕西小区  SA61013     陕西联强  咸阳     展厅     Q5L    1   0
# 42246 2020-10-31  西部区  陕西小区  SA61013     陕西联强  咸阳     展厅  others    1   0
# 42247 2020-10-31  西部区  陕西小区  SA61013     陕西联强  咸阳     线上      A3    2   0
# 42248 2020-10-31  西部区  陕西小区  SA61013     陕西联强  咸阳     线上     A6L    1   0
# 42249 2020-10-31  西部区  陕西小区  SA61016   西安沣东奥诚  西安     展厅     Q5L    1   0
# 42250 2020-10-31  西部区  陕西小区  SA61016   西安沣东奥诚  西安     线上     A6L    1   0
# 42251 2020-10-31  西部区  陕西小区  SA61016   西安沣东奥诚  西安     线上     Q5L    1   0
# 42252 2020-10-31  西部区  陕西小区  SA61017   安康泽泰瑞通  安康     展厅     A4L    1   0
# 42253 2020-10-31  西部区  陕西小区  SA61018   陕西运通瑞迪  西安     展厅     A6L    1   0
# 42254 2020-10-31  西部区  陕西小区  SA61018   陕西运通瑞迪  西安     展厅     Q5L    1   0
# 42255 2020-10-31  西部区  陕西小区  SA61018   陕西运通瑞迪  西安     线上      A3    1   0
# 42256 2020-10-31  西部区  陕西小区  SA61018   陕西运通瑞迪  西安     线上     A4L    2   0
# 42257 2020-10-31  西部区  陕西小区  SA61018   陕西运通瑞迪  西安     线上     A6L    1   0
# 42258 2020-10-31  西部区  陕西小区  SA61018   陕西运通瑞迪  西安     线上      Q3    1   0
# 42259 2020-10-31  西部区  陕西小区  SA61018   陕西运通瑞迪  西安     线上     Q5L    1   0
#
# [42260 rows x 10 columns]

# %%
dataAvailable.head(5)
# Out:
#           日期 大区名称  小区名称    经销商代码    经销商名称  城市  潜客量  大区 客户来源更新 车型new
# 0 2020-10-01  北部区  北京1区  SA11043  北京奥吉通国门  北京    1  A3     展厅   A4L
# 1 2020-10-01  北部区  北京1区  SA11043  北京奥吉通国门  北京    2  A3     展厅   A6L
# 2 2020-10-01  北部区  北京1区  SA11043  北京奥吉通国门  北京    1  A3     展厅    Q3
# 3 2020-10-01  北部区  北京1区  SA11043  北京奥吉通国门  北京    1  A3     展厅   Q5L
# 4 2020-10-01  北部区  北京1区  SA11043  北京奥吉通国门  北京    2  A3     线上   Q5L

# %%
dataMiss
# Out:
#               日期 大区名称   小区名称    经销商代码   经销商名称   城市 潜客量   大区 客户来源更新   车型new
# 0     2020-10-19  东北区   吉林小区  SA15016   兴安盟华奥  兴安盟   1  NaN     展厅  A4 FBU
# 1     2020-10-20  东北区   吉林小区  SA15016   兴安盟华奥  兴安盟   1  NaN     展厅  A6 FBU
# 2     2020-10-20  东北区   吉林小区  SA15016   兴安盟华奥  兴安盟   1  NaN     展厅      Q3
# 3     2020-10-20  东北区   吉林小区  SA15016   兴安盟华奥  兴安盟   1  NaN     展厅     A4L
# 4     2020-10-20  东北区   吉林小区  SA15016   兴安盟华奥  兴安盟   1  NaN     展厅  others
# 5     2020-10-20  东北区   吉林小区  SA15016   兴安盟华奥  兴安盟   1  NaN     展厅      A3
# 6     2020-10-20  东北区   吉林小区  SA15016   兴安盟华奥  兴安盟   1  NaN     展厅  others
# 7     2020-10-20  东北区   吉林小区  SA15016   兴安盟华奥  兴安盟   1  NaN     展厅  others
# 8     2020-10-23  东北区   吉林小区  SA15016   兴安盟华奥  兴安盟   1  NaN     展厅  others
# 9     2020-10-24  东北区   吉林小区  SA15016   兴安盟华奥  兴安盟   1  NaN     展厅     A6L
# 10    2020-10-24  东北区   吉林小区  SA15016   兴安盟华奥  兴安盟   1  NaN     展厅     A6L
# 11    2020-10-26  东北区   吉林小区  SA15016   兴安盟华奥  兴安盟   1  NaN     展厅  A6 FBU
# 12    2020-10-27  东北区   吉林小区  SA15016   兴安盟华奥  兴安盟   1  NaN     展厅     A6L
# 13    2020-10-27  东北区   吉林小区  SA15016   兴安盟华奥  兴安盟   1  NaN     展厅     Q5L
# 14    2020-10-27  东北区   吉林小区  SA15016   兴安盟华奥  兴安盟   1  NaN     展厅     A4L
# 15    2020-10-28  东北区   吉林小区  SA15016   兴安盟华奥  兴安盟   1  NaN     展厅     A6L
# 16    2020-10-28  东北区   吉林小区  SA15016   兴安盟华奥  兴安盟   1  NaN     展厅     A6L
# 17    2020-10-28  东北区   吉林小区  SA15016   兴安盟华奥  兴安盟   1  NaN     展厅     A6L
# 18    2020-10-29  东北区   吉林小区  SA15016   兴安盟华奥  兴安盟   1  NaN     展厅     A4L
# 19    2020-10-30  东北区   吉林小区  SA15016   兴安盟华奥  兴安盟   1  NaN     展厅  A6 FBU
# 20    2020-10-30  东北区   吉林小区  SA15016   兴安盟华奥  兴安盟   1  NaN     展厅     Q2L
# 21    2020-10-02  东北区   吉林小区  SA22002    吉林神华   吉林   1  NaN     展厅     Q5L
# 22    2020-10-02  东北区   吉林小区  SA22002    吉林神华   吉林   1  NaN     展厅      A3
# 23    2020-10-03  东北区   吉林小区  SA22002    吉林神华   吉林   1  NaN     展厅     Q2L
# 24    2020-10-03  东北区   吉林小区  SA22002    吉林神华   吉林   1  NaN     展厅     A4L
# 25    2020-10-03  东北区   吉林小区  SA22002    吉林神华   吉林   1  NaN     展厅     A6L
# 26    2020-10-03  东北区   吉林小区  SA22002    吉林神华   吉林   1  NaN     展厅     A4L
# 27    2020-10-03  东北区   吉林小区  SA22002    吉林神华   吉林   1  NaN     展厅      A3
# 28    2020-10-03  东北区   吉林小区  SA22002    吉林神华   吉林   1  NaN     展厅      Q7
# 29    2020-10-03  东北区   吉林小区  SA22002    吉林神华   吉林   1  NaN     展厅      Q3
# ...          ...  ...    ...      ...     ...  ...  ..  ...    ...     ...
# 66473 2020-10-24  南部区   粤中小区  SA44063    佛山奥泽   佛山   1  NaN     线上     A4L
# 66474 2020-10-29  南部区   长沙小区  SA43021  湖南永通中南   长沙   1  NaN     线上  others
# 66475 2020-10-29  南部区   长沙小区  SA43021  湖南永通中南   长沙   1  NaN     线上     A6L
# 66476 2020-10-29  南部区   长沙小区  SA43021  湖南永通中南   长沙   1  NaN     线上     Q5L
# 66477 2020-10-29  南部区   长沙小区  SA43021  湖南永通中南   长沙   1  NaN     线上     Q2L
# 66478 2020-10-29  南部区   长沙小区  SA43021  湖南永通中南   长沙   1  NaN     线上     A4L
# 66479 2020-10-29  南部区   长沙小区  SA43021  湖南永通中南   长沙   1  NaN     线上     A4L
# 66480 2020-10-29  南部区   长沙小区  SA43021  湖南永通中南   长沙   1  NaN     线上     A6L
# 66481 2020-10-29  南部区   长沙小区  SA43021  湖南永通中南   长沙   1  NaN     线上     A6L
# 66482 2020-10-29  南部区   长沙小区  SA43021  湖南永通中南   长沙   1  NaN     线上     A4L
# 66483 2020-10-29  南部区   长沙小区  SA43021  湖南永通中南   长沙   1  NaN     线上      A3
# 66484 2020-10-30  南部区   长沙小区  SA43021  湖南永通中南   长沙   1  NaN     线上     Q5L
# 66485 2020-10-30  南部区   长沙小区  SA43021  湖南永通中南   长沙   1  NaN     线上      Q3
# 66486 2020-10-29  西部区   成都小区  SA51030   成都奥达通   成都   1  NaN     线上     A6L
# 66487 2020-10-29  西部区   成都小区  SA51030   成都奥达通   成都   1  NaN     线上      Q3
# 66488 2020-10-29  西部区   成都小区  SA51030   成都奥达通   成都   1  NaN     线上     A4L
# 66489 2020-10-29  西部区   成都小区  SA51030   成都奥达通   成都   1  NaN     线上     A4L
# 66490 2020-10-30  西部区   成都小区  SA51030   成都奥达通   成都   1  NaN     线上     Q5L
# 66491 2020-10-31  西部区   成都小区  SA51030   成都奥达通   成都   1  NaN     线上     Q5L
# 66492 2020-10-31  西部区   成都小区  SA51030   成都奥达通   成都   1  NaN     线上     Q2L
# 66493 2020-10-31  西部区   成都小区  SA51030   成都奥达通   成都   1  NaN     线上  others
# 66494 2020-10-31  西部区   成都小区  SA51030   成都奥达通   成都   1  NaN     线上     A4L
# 66495 2020-10-31  西部区   成都小区  SA51030   成都奥达通   成都   1  NaN     线上     A6L
# 66496 2020-10-31  西部区   成都小区  SA51030   成都奥达通   成都   1  NaN     线上      A3
# 66497 2020-10-04  西部区  新青藏小区  SA54001    拉萨康奥   拉萨   1  NaN     线上     Q2L
# 66498 2020-10-04  西部区  新青藏小区  SA54001    拉萨康奥   拉萨   1  NaN     线上     Q2L
# 66499 2020-10-04  西部区  新青藏小区  SA54001    拉萨康奥   拉萨   1  NaN     线上      Q3
# 66500 2020-10-07  西部区  新青藏小区  SA54001    拉萨康奥   拉萨   1  NaN     线上     Q5L
# 66501 2020-10-17  西部区  新青藏小区  SA54001    拉萨康奥   拉萨   1  NaN     线上      Q3
# 66502 2020-10-23  西部区  新青藏小区  SA54001    拉萨康奥   拉萨   1  NaN     线上     Q5L
#
# [66503 rows x 10 columns]

# %%
dataAvailable.head(5)
# Out:
#           日期 大区名称  小区名称    经销商代码    经销商名称  城市  潜客量  大区 客户来源更新 车型new
# 0 2020-10-01  北部区  北京1区  SA11043  北京奥吉通国门  北京    1  A3     展厅   A4L
# 1 2020-10-01  北部区  北京1区  SA11043  北京奥吉通国门  北京    2  A3     展厅   A6L
# 2 2020-10-01  北部区  北京1区  SA11043  北京奥吉通国门  北京    1  A3     展厅    Q3
# 3 2020-10-01  北部区  北京1区  SA11043  北京奥吉通国门  北京    1  A3     展厅   Q5L
# 4 2020-10-01  北部区  北京1区  SA11043  北京奥吉通国门  北京    2  A3     线上   Q5L

# %%
# 图表所需的层次
graphLVL = ["大区名称", "小区名称", "城市", "经销商代码"]

# %%
[['a3', 'a2', 'a4'], ['哈尔滨去', '沈阳区'], ['aa', 'bb'], ['123', '234']]

# %%
pics = []
for pic in graphLVL:
    pics.extend(batDraw(pic))
html = pb.plot_grid(pics, plot_width=300, return_html=True)
# Out:
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead

# %%
with open("tt.html", 'w') as f:
    f.write(html)

# %%
dataUSEstd.head()
# Out:
#   大区名称  小区名称   城市    经销商代码 客户来源更新   车型new  潜客量  dealer汇总      车型占比      日均概率
# 0  东北区  吉林小区  兴安盟  SA15016     展厅      A3   11       237  0.046414  0.354839
# 1  东北区  吉林小区  兴安盟  SA15016     展厅  A4 FBU   12       237  0.050633  0.387097
# 2  东北区  吉林小区  兴安盟  SA15016     展厅     A4L   35       237  0.147679  1.129032
# 3  东北区  吉林小区  兴安盟  SA15016     展厅  A6 FBU   35       237  0.147679  1.129032
# 4  东北区  吉林小区  兴安盟  SA15016     展厅     A6L   64       237  0.270042  2.064516

# %%
dataEsti.head()
# Out:
#   大区名称  小区名称   城市    经销商代码 客户来源更新   车型new  潜客量  dealer汇总      车型占比      日均概率
# 0  东北区  吉林小区  兴安盟  SA15016     展厅      A3   12       258  0.046512  0.387097
# 1  东北区  吉林小区  兴安盟  SA15016     展厅  A4 FBU   13       258  0.050388  0.419355
# 2  东北区  吉林小区  兴安盟  SA15016     展厅     A4L   38       258  0.147287  1.225806
# 3  东北区  吉林小区  兴安盟  SA15016     展厅  A6 FBU   38       258  0.147287  1.225806
# 4  东北区  吉林小区  兴安盟  SA15016     展厅     A6L   70       258  0.271318  2.258065

# %%
dataEsti[dataEsti['经销商代码']=='SA44031']
# Out:
#      大区名称  小区名称  城市    经销商代码 客户来源更新   车型new  潜客量  dealer汇总      车型占比      日均概率
# 9253  南部区  深圳小区  深圳  SA44031     展厅      A3   18      1046  0.017208  0.580645
# 9254  南部区  深圳小区  深圳  SA44031     展厅  A4 FBU    6      1046  0.005736  0.193548
# 9255  南部区  深圳小区  深圳  SA44031     展厅     A4L  215      1046  0.205545  6.935484
# 9256  南部区  深圳小区  深圳  SA44031     展厅      A5    4      1046  0.003824  0.129032
# 9257  南部区  深圳小区  深圳  SA44031     展厅  A6 FBU   28      1046  0.026769  0.903226
# 9258  南部区  深圳小区  深圳  SA44031     展厅     A6L  242      1046  0.231358  7.806452
# 9259  南部区  深圳小区  深圳  SA44031     展厅      A7   13      1046  0.012428  0.419355
# 9260  南部区  深圳小区  深圳  SA44031     展厅     A8L   20      1046  0.019120  0.645161
# 9261  南部区  深圳小区  深圳  SA44031     展厅     Q2L   45      1046  0.043021  1.451613
# 9262  南部区  深圳小区  深圳  SA44031     展厅      Q3   38      1046  0.036329  1.225806
# 9263  南部区  深圳小区  深圳  SA44031     展厅     Q5L  221      1046  0.211281  7.129032
# 9264  南部区  深圳小区  深圳  SA44031     展厅      Q7   51      1046  0.048757  1.645161
# 9265  南部区  深圳小区  深圳  SA44031     展厅      Q8   19      1046  0.018164  0.612903
# 9266  南部区  深圳小区  深圳  SA44031     展厅  others  126      1046  0.120459  4.064516
# 9267  南部区  深圳小区  深圳  SA44031     线上      A3   22       184  0.119565  0.709677
# 9268  南部区  深圳小区  深圳  SA44031     线上  A4 FBU    4       184  0.021739  0.129032
# 9269  南部区  深圳小区  深圳  SA44031     线上     A4L   29       184  0.157609  0.935484
# 9270  南部区  深圳小区  深圳  SA44031     线上      A5    4       184  0.021739  0.129032
# 9271  南部区  深圳小区  深圳  SA44031     线上  A6 FBU    4       184  0.021739  0.129032
# 9272  南部区  深圳小区  深圳  SA44031     线上     A6L   50       184  0.271739  1.612903
# 9273  南部区  深圳小区  深圳  SA44031     线上     A8L    4       184  0.021739  0.129032
# 9274  南部区  深圳小区  深圳  SA44031     线上     Q2L   14       184  0.076087  0.451613
# 9275  南部区  深圳小区  深圳  SA44031     线上      Q3   14       184  0.076087  0.451613
# 9276  南部区  深圳小区  深圳  SA44031     线上     Q5L   14       184  0.076087  0.451613
# 9277  南部区  深圳小区  深圳  SA44031     线上      Q7    7       184  0.038043  0.225806
# 9278  南部区  深圳小区  深圳  SA44031     线上  others   18       184  0.097826  0.580645

# %%
dataUSEstd[dataUSEstd['经销商代码']=='SA44031']
# Out:
#      大区名称  小区名称  城市    经销商代码 客户来源更新   车型new  潜客量  dealer汇总      车型占比      日均概率
# 9156  南部区  深圳小区  深圳  SA44031     展厅      A3   12       716  0.016760  0.387097
# 9157  南部区  深圳小区  深圳  SA44031     展厅  A4 FBU    4       716  0.005587  0.129032
# 9158  南部区  深圳小区  深圳  SA44031     展厅     A4L  147       716  0.205307  4.741935
# 9159  南部区  深圳小区  深圳  SA44031     展厅      A5    3       716  0.004190  0.096774
# 9160  南部区  深圳小区  深圳  SA44031     展厅  A6 FBU   19       716  0.026536  0.612903
# 9161  南部区  深圳小区  深圳  SA44031     展厅     A6L  166       716  0.231844  5.354839
# 9162  南部区  深圳小区  深圳  SA44031     展厅      A7    9       716  0.012570  0.290323
# 9163  南部区  深圳小区  深圳  SA44031     展厅     A8L   14       716  0.019553  0.451613
# 9164  南部区  深圳小区  深圳  SA44031     展厅     Q2L   31       716  0.043296  1.000000
# 9165  南部区  深圳小区  深圳  SA44031     展厅      Q3   26       716  0.036313  0.838710
# 9166  南部区  深圳小区  深圳  SA44031     展厅     Q5L  151       716  0.210894  4.870968
# 9167  南部区  深圳小区  深圳  SA44031     展厅      Q7   35       716  0.048883  1.129032
# 9168  南部区  深圳小区  深圳  SA44031     展厅      Q8   13       716  0.018156  0.419355
# 9169  南部区  深圳小区  深圳  SA44031     展厅  others   86       716  0.120112  2.774194
# 9170  南部区  深圳小区  深圳  SA44031     线上      A3    6        51  0.117647  0.193548
# 9171  南部区  深圳小区  深圳  SA44031     线上  A4 FBU    1        51  0.019608  0.032258
# 9172  南部区  深圳小区  深圳  SA44031     线上     A4L    8        51  0.156863  0.258065
# 9173  南部区  深圳小区  深圳  SA44031     线上      A5    1        51  0.019608  0.032258
# 9174  南部区  深圳小区  深圳  SA44031     线上  A6 FBU    1        51  0.019608  0.032258
# 9175  南部区  深圳小区  深圳  SA44031     线上     A6L   14        51  0.274510  0.451613
# 9176  南部区  深圳小区  深圳  SA44031     线上     A8L    1        51  0.019608  0.032258
# 9177  南部区  深圳小区  深圳  SA44031     线上     Q2L    4        51  0.078431  0.129032
# 9178  南部区  深圳小区  深圳  SA44031     线上      Q3    4        51  0.078431  0.129032
# 9179  南部区  深圳小区  深圳  SA44031     线上     Q5L    4        51  0.078431  0.129032
# 9180  南部区  深圳小区  深圳  SA44031     线上      Q7    2        51  0.039216  0.064516
# 9181  南部区  深圳小区  深圳  SA44031     线上  others    5        51  0.098039  0.161290

# %%
# 轮盘赌算法，应该用不着了，直接用估计值去填坑
import random
maxnum = 10000
pDIS = [0.046414, 0.050633, 0.147679, 0.147679, 0.270042, 0.008439, 0.004219, 0.033755, 0.025316, 0.07173, 0.004219, 0.008439, 0.181435]
pDISsum = []
for i in range(len(pDIS)):
    if pDISsum:
        pDISsum.append(pDISsum[-1] + pDIS[i])
    else:
        pDISsum.append(pDIS[i])
result = [0] * len(pDIS)
for i in range(maxnum):
    rNUM = random.random()
    for n, m in enumerate(pDISsum):
        if rNUM < m:
            result[n] += 1
            break
print(list(map(lambda x: '%.3f' % x, pDIS)))      
print(list(map(lambda x: '%.3f' % (x/maxnum), result)))
# Out:
# ['0.046', '0.051', '0.148', '0.148', '0.270', '0.008', '0.004', '0.034', '0.025', '0.072', '0.004', '0.008', '0.181']
# ['0.049', '0.049', '0.153', '0.145', '0.272', '0.008', '0.003', '0.031', '0.023', '0.071', '0.005', '0.009', '0.182']

# %%
dataMiss['大区'] = dataMiss['大区名称'].map(settingHash['bigarea'])

# %%
dataMiss.head()
# Out:
#           日期 大区名称  小区名称    经销商代码  经销商名称   城市 潜客量  大区 客户来源更新   车型new
# 0 2020-10-19  东北区  吉林小区  SA15016  兴安盟华奥  兴安盟   1  A1     展厅  others
# 1 2020-10-20  东北区  吉林小区  SA15016  兴安盟华奥  兴安盟   1  A1     展厅     A4L
# 2 2020-10-20  东北区  吉林小区  SA15016  兴安盟华奥  兴安盟   1  A1     展厅      A3
# 3 2020-10-20  东北区  吉林小区  SA15016  兴安盟华奥  兴安盟   1  A1     展厅  A6 FBU
# 4 2020-10-20  东北区  吉林小区  SA15016  兴安盟华奥  兴安盟   1  A1     展厅  others

# %%
dataAvailable.head()
# Out:
#           日期 大区名称  小区名称    经销商代码    经销商名称  城市  潜客量  大区 客户来源更新 车型new
# 0 2020-10-01  北部区  北京1区  SA11043  北京奥吉通国门  北京    1  A3     展厅   A4L
# 1 2020-10-01  北部区  北京1区  SA11043  北京奥吉通国门  北京    2  A3     展厅   A6L
# 2 2020-10-01  北部区  北京1区  SA11043  北京奥吉通国门  北京    1  A3     展厅    Q3
# 3 2020-10-01  北部区  北京1区  SA11043  北京奥吉通国门  北京    1  A3     展厅   Q5L
# 4 2020-10-01  北部区  北京1区  SA11043  北京奥吉通国门  北京    2  A3     线上   Q5L

# %%
databookNew = dataAvailable.append(dataMiss, ignore_index=True)

# %%
databookNew = databookNew.groupby(['日期', '大区名称', '大区', '小区名称', '经销商代码', '经销商名称', '城市', '客户来源更新', '车型new'])['潜客量'].sum().reset_index()

# %%
databookNew.to_excel('Data/rebuild.xlsx', encoding='utf8', header=True, index=False)
