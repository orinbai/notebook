# %%
import numpy as np
import pandas as pd
from bokeh.io import output_notebook
import random
output_notebook()
from bokeh.plotting import figure, show
from bokeh.palettes import brewer
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
def transNUM(s):
    return list(map(float, eval(s)))

def columnSLT(s, cname):
    return list(map(lambda x: x.startswith(s),cname))

# %%
resHash = {}
with open("Genetic.mi.log") as LOG:
    for line in LOG:
        fields = line.strip().split("\t")
        # Generate, MaxFitness, AvgFitness, MinFitness, Time
        resHash.setdefault(fields[4], {})
        GenNum = int(fields[0])
        maxFit = transNUM(fields[1])
        avgFit = transNUM(fields[2])
        for i in range(len(maxFit)):
            if i == 0:
                resHash[fields[4]].setdefault("Avg-Global", [])
                resHash[fields[4]].setdefault("Max-Global", [])
                resHash[fields[4]]["Avg-Global"].append(avgFit[i])
                resHash[fields[4]]["Max-Global"].append(maxFit[i])
            else:
                resHash[fields[4]].setdefault("Avg-Island%d" % i, [])
                resHash[fields[4]].setdefault("Max-Island%d" % i, [])
                resHash[fields[4]]["Avg-Island%d" % i].append(avgFit[i])
                resHash[fields[4]]["Max-Island%d" % i].append(maxFit[i])
# print(resHash.keys())
# print(resHash["1603437513"])
# df = pd.DataFrame(resHash["1603712383"])
df = pd.DataFrame(resHash["1604043611"])

# %%
def iplot(df, cname):
    tmpdf = df.loc[:, columnSLT(cname, df.columns.values)]
    print(tmpdf.loc[:, [False, True, True, True, True]].idxmax(axis=1))

# %%
iplot(df, "Max")
# Out:
# 0       Max-Island2
# 1       Max-Island2
# 2       Max-Island2
# 3       Max-Island2
# 4       Max-Island3
# 5       Max-Island3
# 6       Max-Island3
# 7       Max-Island3
# 8       Max-Island3
# 9       Max-Island3
# 10      Max-Island4
# 11      Max-Island4
# 12      Max-Island4
# 13      Max-Island4
# 14      Max-Island4
# 15      Max-Island4
# 16      Max-Island4
# 17      Max-Island4
# 18      Max-Island4
# 19      Max-Island4
# 20      Max-Island4
# 21      Max-Island4
# 22      Max-Island4
# 23      Max-Island4
# 24      Max-Island4
# 25      Max-Island4
# 26      Max-Island4
# 27      Max-Island4
# 28      Max-Island4
# 29      Max-Island4
#            ...
# 2970    Max-Island4
# 2971    Max-Island3
# 2972    Max-Island1
# 2973    Max-Island2
# 2974    Max-Island3
# 2975    Max-Island4
# 2976    Max-Island1
# 2977    Max-Island1
# 2978    Max-Island1
# 2979    Max-Island1
# 2980    Max-Island3
# 2981    Max-Island3
# 2982    Max-Island3
# 2983    Max-Island3
# ...

# %%
def sumPlot(df, dataClass):
    tmpdf = df.loc[:, columnSLT(dataClass, df.columns.values)]
    colors = brewer["Spectral"][tmpDF.shape[1]]
    p = figure(
        tools = "pan, box_zoom, reset, save",
        title = "Genetic Algorithms-%s Fitness" % dataClass,
        width = 800,
        height = 1440
    )
    for i in range(len(tmpdf.columns.values)):
        if i == 0:
            lb_str = "Global"
        else:
            lb_str = "Island%d" % i
        p.line(tmpdf.index, tmpdf[tmpdf.columns.values[i]], color=colors[i], legend_label=lb_str)
    show(p)
    p.legend.orientation = "horizontal"
    p.legend.location = "center_right"

# %%
sumPlot(df, "Max")
# Out:
#   <div class="bk-root" id="422affa8-9876-4641-93d9-9fd6e8113662" data-root-id="9115"></div>
